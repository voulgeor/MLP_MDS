# %%
countries = [
{'timezones': ['Europe/Andorra'], 'code': 'AD', 'continent': 'Europe', 'name': 'Andorra', 'capital': 'Andorra la Vella'},
{'timezones': ['Asia/Kabul'], 'code': 'AF', 'continent': 'Asia', 'name': 'Afghanistan', 'capital': 'Kabul'},
{'timezones': ['America/Antigua'], 'code': 'AG', 'continent': 'North America', 'name': 'Antigua and Barbuda', 'capital': "St. John's"},
{'timezones': ['Europe/Tirane'], 'code': 'AL', 'continent': 'Europe', 'name': 'Albania', 'capital': 'Tirana'},
{'timezones': ['Asia/Yerevan'], 'code': 'AM', 'continent': 'Asia', 'name': 'Armenia', 'capital': 'Yerevan'},
{'timezones': ['Africa/Luanda'], 'code': 'AO', 'continent': 'Africa', 'name': 'Angola', 'capital': 'Luanda'},
{'timezones': ['America/Argentina/Buenos_Aires', 'America/Argentina/Cordoba', 'America/Argentina/Jujuy', 'America/Argentina/Tucuman', 'America/Argentina/Catamarca', 'America/Argentina/La_Rioja', 'America/Argentina/San_Juan', 'America/Argentina/Mendoza', 'America/Argentina/Rio_Gallegos', 'America/Argentina/Ushuaia'], 'code': 'AR', 'continent': 'South America', 'name': 'Argentina', 'capital': 'Buenos Aires'},
{'timezones': ['Europe/Vienna'], 'code': 'AT', 'continent': 'Europe', 'name': 'Austria', 'capital': 'Vienna'},
{'timezones': ['Australia/Lord_Howe', 'Australia/Hobart', 'Australia/Currie', 'Australia/Melbourne', 'Australia/Sydney', 'Australia/Broken_Hill', 'Australia/Brisbane', 'Australia/Lindeman', 'Australia/Adelaide', 'Australia/Darwin', 'Australia/Perth'], 'code': 'AU', 'continent': 'Oceania', 'name': 'Australia', 'capital': 'Canberra'},
{'timezones': ['Asia/Baku'], 'code': 'AZ', 'continent': 'Asia', 'name': 'Azerbaijan', 'capital': 'Baku'},
{'timezones': ['America/Barbados'], 'code': 'BB', 'continent': 'North America', 'name': 'Barbados', 'capital': 'Bridgetown'},
{'timezones': ['Asia/Dhaka'], 'code': 'BD', 'continent': 'Asia', 'name': 'Bangladesh', 'capital': 'Dhaka'},
{'timezones': ['Europe/Brussels'], 'code': 'BE', 'continent': 'Europe', 'name': 'Belgium', 'capital': 'Brussels'},
{'timezones': ['Africa/Ouagadougou'], 'code': 'BF', 'continent': 'Africa', 'name': 'Burkina Faso', 'capital': 'Ouagadougou'},
{'timezones': ['Europe/Sofia'], 'code': 'BG', 'continent': 'Europe', 'name': 'Bulgaria', 'capital': 'Sofia'},
{'timezones': ['Asia/Bahrain'], 'code': 'BH', 'continent': 'Asia', 'name': 'Bahrain', 'capital': 'Manama'},
{'timezones': ['Africa/Bujumbura'], 'code': 'BI', 'continent': 'Africa', 'name': 'Burundi', 'capital': 'Bujumbura'},
{'timezones': ['Africa/Porto-Novo'], 'code': 'BJ', 'continent': 'Africa', 'name': 'Benin', 'capital': 'Porto-Novo'},
{'timezones': ['Asia/Brunei'], 'code': 'BN', 'continent': 'Asia', 'name': 'Brunei Darussalam', 'capital': 'Bandar Seri Begawan'},
{'timezones': ['America/La_Paz'], 'code': 'BO', 'continent': 'South America', 'name': 'Bolivia', 'capital': 'Sucre'},
{'timezones': ['America/Noronha', 'America/Belem', 'America/Fortaleza', 'America/Recife', 'America/Araguaina', 'America/Maceio', 'America/Bahia', 'America/Sao_Paulo', 'America/Campo_Grande', 'America/Cuiaba', 'America/Porto_Velho', 'America/Boa_Vista', 'America/Manaus', 'America/Eirunepe', 'America/Rio_Branco'], 'code': 'BR', 'continent': 'South America', 'name': 'Brazil', 'capital': 'Bras\xc3\xadlia'},
{'timezones': ['America/Nassau'], 'code': 'BS', 'continent': 'North America', 'name': 'Bahamas', 'capital': 'Nassau'},
{'timezones': ['Asia/Thimphu'], 'code': 'BT', 'continent': 'Asia', 'name': 'Bhutan', 'capital': 'Thimphu'},
{'timezones': ['Africa/Gaborone'], 'code': 'BW', 'continent': 'Africa', 'name': 'Botswana', 'capital': 'Gaborone'},
{'timezones': ['Europe/Minsk'], 'code': 'BY', 'continent': 'Europe', 'name': 'Belarus', 'capital': 'Minsk'},
{'timezones': ['America/Belize'], 'code': 'BZ', 'continent': 'North America', 'name': 'Belize', 'capital': 'Belmopan'},
{'timezones': ['America/St_Johns', 'America/Halifax', 'America/Glace_Bay', 'America/Moncton', 'America/Goose_Bay', 'America/Blanc-Sablon', 'America/Montreal', 'America/Toronto', 'America/Nipigon', 'America/Thunder_Bay', 'America/Pangnirtung', 'America/Iqaluit', 'America/Atikokan', 'America/Rankin_Inlet', 'America/Winnipeg', 'America/Rainy_River', 'America/Cambridge_Bay', 'America/Regina', 'America/Swift_Current', 'America/Edmonton', 'America/Yellowknife', 'America/Inuvik', 'America/Dawson_Creek', 'America/Vancouver', 'America/Whitehorse', 'America/Dawson'], 'code': 'CA', 'continent': 'North America', 'name': 'Canada', 'capital': 'Ottawa'},
{'timezones': ['Africa/Kinshasa', 'Africa/Lubumbashi'], 'code': 'CD', 'continent': 'Africa', 'name': 'Democratic Republic of the Congo', 'capital': 'Kinshasa'},
{'timezones': ['Africa/Brazzaville'], 'code': 'CG', 'continent': 'Africa', 'name': 'Republic of the Congo', 'capital': 'Brazzaville'},
{'timezones': ['Africa/Abidjan'], 'code': 'CI', 'continent': 'Africa', 'name': "C\xc3\xb4te d'Ivoire", 'capital': 'Yamoussoukro'},
{'timezones': ['America/Santiago', 'Pacific/Easter'], 'code': 'CL', 'continent': 'South America', 'name': 'Chile', 'capital': 'Santiago'},
{'timezones': ['Africa/Douala'], 'code': 'CM', 'continent': 'Africa', 'name': 'Cameroon', 'capital': 'Yaound\xc3\xa9'},
{'timezones': ['Asia/Shanghai', 'Asia/Harbin', 'Asia/Chongqing', 'Asia/Urumqi', 'Asia/Kashgar'], 'code': 'CN', 'continent': 'Asia', 'name': "People's Republic of China", 'capital': 'Beijing'},
{'timezones': ['America/Bogota'], 'code': 'CO', 'continent': 'South America', 'name': 'Colombia', 'capital': 'Bogot\xc3\xa1'},
{'timezones': ['America/Costa_Rica'], 'code': 'CR', 'continent': 'North America', 'name': 'Costa Rica', 'capital': 'San Jos\xc3\xa9'},
{'timezones': ['America/Havana'], 'code': 'CU', 'continent': 'North America', 'name': 'Cuba', 'capital': 'Havana'},
{'timezones': ['Atlantic/Cape_Verde'], 'code': 'CV', 'continent': 'Africa', 'name': 'Cape Verde', 'capital': 'Praia'},
{'timezones': ['Asia/Nicosia'], 'code': 'CY', 'continent': 'Asia', 'name': 'Cyprus', 'capital': 'Nicosia'},
{'timezones': ['Europe/Prague'], 'code': 'CZ', 'continent': 'Europe', 'name': 'Czech Republic', 'capital': 'Prague'},
{'timezones': ['Europe/Berlin'], 'code': 'DE', 'continent': 'Europe', 'name': 'Germany', 'capital': 'Berlin'},
{'timezones': ['Africa/Djibouti'], 'code': 'DJ', 'continent': 'Africa', 'name': 'Djibouti', 'capital': 'Djibouti City'},
{'timezones': ['Europe/Copenhagen'], 'code': 'DK', 'continent': 'Europe', 'name': 'Denmark', 'capital': 'Copenhagen'},
{'timezones': ['America/Dominica'], 'code': 'DM', 'continent': 'North America', 'name': 'Dominica', 'capital': 'Roseau'},
{'timezones': ['America/Santo_Domingo'], 'code': 'DO', 'continent': 'North America', 'name': 'Dominican Republic', 'capital': 'Santo Domingo'},
{'timezones': ['America/Guayaquil', 'Pacific/Galapagos'], 'code': 'EC', 'continent': 'South America', 'name': 'Ecuador', 'capital': 'Quito'},
{'timezones': ['Europe/Tallinn'], 'code': 'EE', 'continent': 'Europe', 'name': 'Estonia', 'capital': 'Tallinn'},
{'timezones': ['Africa/Cairo'], 'code': 'EG', 'continent': 'Africa', 'name': 'Egypt', 'capital': 'Cairo'},
{'timezones': ['Africa/Asmera'], 'code': 'ER', 'continent': 'Africa', 'name': 'Eritrea', 'capital': 'Asmara'},
{'timezones': ['Africa/Addis_Ababa'], 'code': 'ET', 'continent': 'Africa', 'name': 'Ethiopia', 'capital': 'Addis Ababa'},
{'timezones': ['Europe/Helsinki'], 'code': 'FI', 'continent': 'Europe', 'name': 'Finland', 'capital': 'Helsinki'},
{'timezones': ['Pacific/Fiji'], 'code': 'FJ', 'continent': 'Oceania', 'name': 'Fiji', 'capital': 'Suva'},
{'timezones': ['Europe/Paris'], 'code': 'FR', 'continent': 'Europe', 'name': 'France', 'capital': 'Paris'},
{'timezones': ['Africa/Libreville'], 'code': 'GA', 'continent': 'Africa', 'name': 'Gabon', 'capital': 'Libreville'},
{'timezones': ['Asia/Tbilisi'], 'code': 'GE', 'continent': 'Asia', 'name': 'Georgia', 'capital': 'Tbilisi'},
{'timezones': ['Africa/Accra'], 'code': 'GH', 'continent': 'Africa', 'name': 'Ghana', 'capital': 'Accra'},
{'timezones': ['Africa/Banjul'], 'code': 'GM', 'continent': 'Africa', 'name': 'The Gambia', 'capital': 'Banjul'},
{'timezones': ['Africa/Conakry'], 'code': 'GN', 'continent': 'Africa', 'name': 'Guinea', 'capital': 'Conakry'},
{'timezones': ['Europe/Athens'], 'code': 'GR', 'continent': 'Europe', 'name': 'Greece', 'capital': 'Athens'},
{'timezones': ['America/Guatemala'], 'code': 'GT', 'continent': 'North America', 'name': 'Guatemala', 'capital': 'Guatemala City'},
{'timezones': ['America/Guatemala'], 'code': 'HT', 'continent': 'North America', 'name': 'Haiti', 'capital': 'Port-au-Prince'},
{'timezones': ['Africa/Bissau'], 'code': 'GW', 'continent': 'Africa', 'name': 'Guinea-Bissau', 'capital': 'Bissau'},
{'timezones': ['America/Guyana'], 'code': 'GY', 'continent': 'South America', 'name': 'Guyana', 'capital': 'Georgetown'},
{'timezones': ['America/Tegucigalpa'], 'code': 'HN', 'continent': 'North America', 'name': 'Honduras', 'capital': 'Tegucigalpa'},
{'timezones': ['Europe/Budapest'], 'code': 'HU', 'continent': 'Europe', 'name': 'Hungary', 'capital': 'Budapest'},
{'timezones': ['Asia/Jakarta', 'Asia/Pontianak', 'Asia/Makassar', 'Asia/Jayapura'], 'code': 'ID', 'continent': 'Asia', 'name': 'Indonesia', 'capital': 'Jakarta'},
{'timezones': ['Europe/Dublin'], 'code': 'IE', 'continent': 'Europe', 'name': 'Republic of Ireland', 'capital': 'Dublin'},
{'timezones': ['Asia/Jerusalem'], 'code': 'IL', 'continent': 'Asia', 'name': 'Israel', 'capital': 'Jerusalem'},
{'timezones': ['Asia/Calcutta'], 'code': 'IN', 'continent': 'Asia', 'name': 'India', 'capital': 'New Delhi'},
{'timezones': ['Asia/Baghdad'], 'code': 'IQ', 'continent': 'Asia', 'name': 'Iraq', 'capital': 'Baghdad'},
{'timezones': ['Asia/Tehran'], 'code': 'IR', 'continent': 'Asia', 'name': 'Iran', 'capital': 'Tehran'},
{'timezones': ['Atlantic/Reykjavik'], 'code': 'IS', 'continent': 'Europe', 'name': 'Iceland', 'capital': 'Reykjav\xc3\xadk'},
{'timezones': ['Europe/Rome'], 'code': 'IT', 'continent': 'Europe', 'name': 'Italy', 'capital': 'Rome'},
{'timezones': ['America/Jamaica'], 'code': 'JM', 'continent': 'North America', 'name': 'Jamaica', 'capital': 'Kingston'},
{'timezones': ['Asia/Amman'], 'code': 'JO', 'continent': 'Asia', 'name': 'Jordan', 'capital': 'Amman'},
{'timezones': ['Asia/Tokyo'], 'code': 'JP', 'continent': 'Asia', 'name': 'Japan', 'capital': 'Tokyo'},
{'timezones': ['Africa/Nairobi'], 'code': 'KE', 'continent': 'Africa', 'name': 'Kenya', 'capital': 'Nairobi'},
{'timezones': ['Asia/Bishkek'], 'code': 'KG', 'continent': 'Asia', 'name': 'Kyrgyzstan', 'capital': 'Bishkek'},
{'timezones': ['Pacific/Tarawa', 'Pacific/Enderbury', 'Pacific/Kiritimati'], 'code': 'KI', 'continent': 'Oceania', 'name': 'Kiribati', 'capital': 'Tarawa'},
{'timezones': ['Asia/Pyongyang'], 'code': 'KP', 'continent': 'Asia', 'name': 'North Korea', 'capital': 'Pyongyang'},
{'timezones': ['Asia/Seoul'], 'code': 'KR', 'continent': 'Asia', 'name': 'South Korea', 'capital': 'Seoul'},
{'timezones': ['Asia/Kuwait'], 'code': 'KW', 'continent': 'Asia', 'name': 'Kuwait', 'capital': 'Kuwait City'},
{'timezones': ['Asia/Beirut'], 'code': 'LB', 'continent': 'Asia', 'name': 'Lebanon', 'capital': 'Beirut'},
{'timezones': ['Europe/Vaduz'], 'code': 'LI', 'continent': 'Europe', 'name': 'Liechtenstein', 'capital': 'Vaduz'},
{'timezones': ['Africa/Monrovia'], 'code': 'LR', 'continent': 'Africa', 'name': 'Liberia', 'capital': 'Monrovia'},
{'timezones': ['Africa/Maseru'], 'code': 'LS', 'continent': 'Africa', 'name': 'Lesotho', 'capital': 'Maseru'},
{'timezones': ['Europe/Vilnius'], 'code': 'LT', 'continent': 'Europe', 'name': 'Lithuania', 'capital': 'Vilnius'},
{'timezones': ['Europe/Luxembourg'], 'code': 'LU', 'continent': 'Europe', 'name': 'Luxembourg', 'capital': 'Luxembourg City'},
{'timezones': ['Europe/Riga'], 'code': 'LV', 'continent': 'Europe', 'name': 'Latvia', 'capital': 'Riga'},
{'timezones': ['Africa/Tripoli'], 'code': 'LY', 'continent': 'Africa', 'name': 'Libya', 'capital': 'Tripoli'},
{'timezones': ['Indian/Antananarivo'], 'code': 'MG', 'continent': 'Africa', 'name': 'Madagascar', 'capital': 'Antananarivo'},
{'timezones': ['Pacific/Majuro', 'Pacific/Kwajalein'], 'code': 'MH', 'continent': 'Oceania', 'name': 'Marshall Islands', 'capital': 'Majuro'},
{'timezones': ['Europe/Skopje'], 'code': 'MK', 'continent': 'Europe', 'name': 'Macedonia', 'capital': 'Skopje'},
{'timezones': ['Africa/Bamako'], 'code': 'ML', 'continent': 'Africa', 'name': 'Mali', 'capital': 'Bamako'},
{'timezones': ['Asia/Rangoon'], 'code': 'MM', 'continent': 'Asia', 'name': 'Myanmar', 'capital': 'Naypyidaw'},
{'timezones': ['Asia/Ulaanbaatar', 'Asia/Hovd', 'Asia/Choibalsan'], 'code': 'MN', 'continent': 'Asia', 'name': 'Mongolia', 'capital': 'Ulaanbaatar'},
{'timezones': ['Africa/Nouakchott'], 'code': 'MR', 'continent': 'Africa', 'name': 'Mauritania', 'capital': 'Nouakchott'},
{'timezones': ['Europe/Malta'], 'code': 'MT', 'continent': 'Europe', 'name': 'Malta', 'capital': 'Valletta'},
{'timezones': ['Indian/Mauritius'], 'code': 'MU', 'continent': 'Africa', 'name': 'Mauritius', 'capital': 'Port Louis'},
{'timezones': ['Indian/Maldives'], 'code': 'MV', 'continent': 'Asia', 'name': 'Maldives', 'capital': 'Mal\xc3\xa9'},
{'timezones': ['Africa/Blantyre'], 'code': 'MW', 'continent': 'Africa', 'name': 'Malawi', 'capital': 'Lilongwe'},
{'timezones': ['America/Mexico_City', 'America/Cancun', 'America/Merida', 'America/Monterrey', 'America/Mazatlan', 'America/Chihuahua', 'America/Hermosillo', 'America/Tijuana'], 'code': 'MX', 'continent': 'North America', 'name': 'Mexico', 'capital': 'Mexico City'},
{'timezones': ['Asia/Kuala_Lumpur', 'Asia/Kuching'], 'code': 'MY', 'continent': 'Asia', 'name': 'Malaysia', 'capital': 'Kuala Lumpur'},
{'timezones': ['Africa/Maputo'], 'code': 'MZ', 'continent': 'Africa', 'name': 'Mozambique', 'capital': 'Maputo'},
{'timezones': ['Africa/Windhoek'], 'code': 'NA', 'continent': 'Africa', 'name': 'Namibia', 'capital': 'Windhoek'},
{'timezones': ['Africa/Niamey'], 'code': 'NE', 'continent': 'Africa', 'name': 'Niger', 'capital': 'Niamey'},
{'timezones': ['Africa/Lagos'], 'code': 'NG', 'continent': 'Africa', 'name': 'Nigeria', 'capital': 'Abuja'},
{'timezones': ['America/Managua'], 'code': 'NI', 'continent': 'North America', 'name': 'Nicaragua', 'capital': 'Managua'},
{'timezones': ['Europe/Amsterdam'], 'code': 'NL', 'continent': 'Europe', 'name': 'Kingdom of the Netherlands', 'capital': 'Amsterdam'},
{'timezones': ['Europe/Oslo'], 'code': 'NO', 'continent': 'Europe', 'name': 'Norway', 'capital': 'Oslo'},
{'timezones': ['Asia/Katmandu'], 'code': 'NP', 'continent': 'Asia', 'name': 'Nepal', 'capital': 'Kathmandu'},
{'timezones': ['Pacific/Nauru'], 'code': 'NR', 'continent': 'Oceania', 'name': 'Nauru', 'capital': 'Yaren'},
{'timezones': ['Pacific/Auckland', 'Pacific/Chatham'], 'code': 'NZ', 'continent': 'Oceania', 'name': 'New Zealand', 'capital': 'Wellington'},
{'timezones': ['Asia/Muscat'], 'code': 'OM', 'continent': 'Asia', 'name': 'Oman', 'capital': 'Muscat'},
{'timezones': ['America/Panama'], 'code': 'PA', 'continent': 'North America', 'name': 'Panama', 'capital': 'Panama City'},
{'timezones': ['America/Lima'], 'code': 'PE', 'continent': 'South America', 'name': 'Peru', 'capital': 'Lima'},
{'timezones': ['Pacific/Port_Moresby'], 'code': 'PG', 'continent': 'Oceania', 'name': 'Papua New Guinea', 'capital': 'Port Moresby'},
{'timezones': ['Asia/Manila'], 'code': 'PH', 'continent': 'Asia', 'name': 'Philippines', 'capital': 'Manila'},
{'timezones': ['Asia/Karachi'], 'code': 'PK', 'continent': 'Asia', 'name': 'Pakistan', 'capital': 'Islamabad'},
{'timezones': ['Europe/Warsaw'], 'code': 'PL', 'continent': 'Europe', 'name': 'Poland', 'capital': 'Warsaw'},
{'timezones': ['Europe/Lisbon', 'Atlantic/Madeira', 'Atlantic/Azores'], 'code': 'PT', 'continent': 'Europe', 'name': 'Portugal', 'capital': 'Lisbon'},
{'timezones': ['Pacific/Palau'], 'code': 'PW', 'continent': 'Oceania', 'name': 'Palau', 'capital': 'Ngerulmud'},
{'timezones': ['America/Asuncion'], 'code': 'PY', 'continent': 'South America', 'name': 'Paraguay', 'capital': 'Asunci\xc3\xb3n'},
{'timezones': ['Asia/Qatar'], 'code': 'QA', 'continent': 'Asia', 'name': 'Qatar', 'capital': 'Doha'},
{'timezones': ['Europe/Bucharest'], 'code': 'RO', 'continent': 'Europe', 'name': 'Romania', 'capital': 'Bucharest'},
{'timezones': ['Europe/Kaliningrad', 'Europe/Moscow', 'Europe/Volgograd', 'Europe/Samara', 'Asia/Yekaterinburg', 'Asia/Omsk', 'Asia/Novosibirsk', 'Asia/Krasnoyarsk', 'Asia/Irkutsk', 'Asia/Yakutsk', 'Asia/Vladivostok', 'Asia/Sakhalin', 'Asia/Magadan', 'Asia/Kamchatka', 'Asia/Anadyr'], 'code': 'RU', 'continent': 'Europe', 'name': 'Russia', 'capital': 'Moscow'},
{'timezones': ['Africa/Kigali'], 'code': 'RW', 'continent': 'Africa', 'name': 'Rwanda', 'capital': 'Kigali'},
{'timezones': ['Asia/Riyadh'], 'code': 'SA', 'continent': 'Asia', 'name': 'Saudi Arabia', 'capital': 'Riyadh'},
{'timezones': ['Pacific/Guadalcanal'], 'code': 'SB', 'continent': 'Oceania', 'name': 'Solomon Islands', 'capital': 'Honiara'},
{'timezones': ['Indian/Mahe'], 'code': 'SC', 'continent': 'Africa', 'name': 'Seychelles', 'capital': 'Victoria'},
{'timezones': ['Africa/Khartoum'], 'code': 'SD', 'continent': 'Africa', 'name': 'Sudan', 'capital': 'Khartoum'},
{'timezones': ['Europe/Stockholm'], 'code': 'SE', 'continent': 'Europe', 'name': 'Sweden', 'capital': 'Stockholm'},
{'timezones': ['Asia/Singapore'], 'code': 'SG', 'continent': 'Asia', 'name': 'Singapore', 'capital': 'Singapore'},
{'timezones': ['Europe/Ljubljana'], 'code': 'SI', 'continent': 'Europe', 'name': 'Slovenia', 'capital': 'Ljubljana'},
{'timezones': ['Europe/Bratislava'], 'code': 'SK', 'continent': 'Europe', 'name': 'Slovakia', 'capital': 'Bratislava'},
{'timezones': ['Africa/Freetown'], 'code': 'SL', 'continent': 'Africa', 'name': 'Sierra Leone', 'capital': 'Freetown'},
{'timezones': ['Europe/San_Marino'], 'code': 'SM', 'continent': 'Europe', 'name': 'San Marino', 'capital': 'San Marino'},
{'timezones': ['Africa/Dakar'], 'code': 'SN', 'continent': 'Africa', 'name': 'Senegal', 'capital': 'Dakar'},
{'timezones': ['Africa/Mogadishu'], 'code': 'SO', 'continent': 'Africa', 'name': 'Somalia', 'capital': 'Mogadishu'},
{'timezones': ['America/Paramaribo'], 'code': 'SR', 'continent': 'South America', 'name': 'Suriname', 'capital': 'Paramaribo'},
{'timezones': ['Africa/Sao_Tome'], 'code': 'ST', 'continent': 'Africa', 'name': 'S\xc3\xa3o Tom\xc3\xa9 and Pr\xc3\xadncipe', 'capital': 'S\xc3\xa3o Tom\xc3\xa9'},
{'timezones': ['Asia/Damascus'], 'code': 'SY', 'continent': 'Asia', 'name': 'Syria', 'capital': 'Damascus'},
{'timezones': ['Africa/Lome'], 'code': 'TG', 'continent': 'Africa', 'name': 'Togo', 'capital': 'Lom\xc3\xa9'},
{'timezones': ['Asia/Bangkok'], 'code': 'TH', 'continent': 'Asia', 'name': 'Thailand', 'capital': 'Bangkok'},
{'timezones': ['Asia/Dushanbe'], 'code': 'TJ', 'continent': 'Asia', 'name': 'Tajikistan', 'capital': 'Dushanbe'},
{'timezones': ['Asia/Ashgabat'], 'code': 'TM', 'continent': 'Asia', 'name': 'Turkmenistan', 'capital': 'Ashgabat'},
{'timezones': ['Africa/Tunis'], 'code': 'TN', 'continent': 'Africa', 'name': 'Tunisia', 'capital': 'Tunis'},
{'timezones': ['Pacific/Tongatapu'], 'code': 'TO', 'continent': 'Oceania', 'name': 'Tonga', 'capital': 'Nuku\xca\xbbalofa'},
{'timezones': ['Europe/Istanbul'], 'code': 'TR', 'continent': 'Asia', 'name': 'Turkey', 'capital': 'Ankara'},
{'timezones': ['America/Port_of_Spain'], 'code': 'TT', 'continent': 'North America', 'name': 'Trinidad and Tobago', 'capital': 'Port of Spain'},
{'timezones': ['Pacific/Funafuti'], 'code': 'TV', 'continent': 'Oceania', 'name': 'Tuvalu', 'capital': 'Funafuti'},
{'timezones': ['Africa/Dar_es_Salaam'], 'code': 'TZ', 'continent': 'Africa', 'name': 'Tanzania', 'capital': 'Dodoma'},
{'timezones': ['Europe/Kiev', 'Europe/Uzhgorod', 'Europe/Zaporozhye', 'Europe/Simferopol'], 'code': 'UA', 'continent': 'Europe', 'name': 'Ukraine', 'capital': 'Kiev'},
{'timezones': ['Africa/Kampala'], 'code': 'UG', 'continent': 'Africa', 'name': 'Uganda', 'capital': 'Kampala'},
{'timezones': ['America/New_York', 'America/Detroit', 'America/Kentucky/Louisville', 'America/Kentucky/Monticello', 'America/Indiana/Indianapolis', 'America/Indiana/Marengo', 'America/Indiana/Knox', 'America/Indiana/Vevay', 'America/Chicago', 'America/Indiana/Vincennes', 'America/Indiana/Petersburg', 'America/Menominee', 'America/North_Dakota/Center', 'America/North_Dakota/New_Salem', 'America/Denver', 'America/Boise', 'America/Shiprock', 'America/Phoenix', 'America/Los_Angeles', 'America/Anchorage', 'America/Juneau', 'America/Yakutat', 'America/Nome', 'America/Adak', 'Pacific/Honolulu'], 'code': 'US', 'continent': 'North America', 'name': 'United States', 'capital': 'Washington, D.C.'},
{'timezones': ['America/Montevideo'], 'code': 'UY', 'continent': 'South America', 'name': 'Uruguay', 'capital': 'Montevideo'},
{'timezones': ['Asia/Samarkand', 'Asia/Tashkent'], 'code': 'UZ', 'continent': 'Asia', 'name': 'Uzbekistan', 'capital': 'Tashkent'},
{'timezones': ['Europe/Vatican'], 'code': 'VA', 'continent': 'Europe', 'name': 'Vatican City', 'capital': 'Vatican City'},
{'timezones': ['America/Caracas'], 'code': 'VE', 'continent': 'South America', 'name': 'Venezuela', 'capital': 'Caracas'},
{'timezones': ['Asia/Saigon'], 'code': 'VN', 'continent': 'Asia', 'name': 'Vietnam', 'capital': 'Hanoi'},
{'timezones': ['Pacific/Efate'], 'code': 'VU', 'continent': 'Oceania', 'name': 'Vanuatu', 'capital': 'Port Vila'},
{'timezones': ['Asia/Aden'], 'code': 'YE', 'continent': 'Asia', 'name': 'Yemen', 'capital': "Sana'a"},
{'timezones': ['Africa/Lusaka'], 'code': 'ZM', 'continent': 'Africa', 'name': 'Zambia', 'capital': 'Lusaka'},
{'timezones': ['Africa/Harare'], 'code': 'ZW', 'continent': 'Africa', 'name': 'Zimbabwe', 'capital': 'Harare'},
{'timezones': ['Africa/Algiers'], 'code': 'DZ', 'continent': 'Africa', 'name': 'Algeria', 'capital': 'Algiers'},
{'timezones': ['Europe/Sarajevo'], 'code': 'BA', 'continent': 'Europe', 'name': 'Bosnia and Herzegovina', 'capital': 'Sarajevo'},
{'timezones': ['Asia/Phnom_Penh'], 'code': 'KH', 'continent': 'Asia', 'name': 'Cambodia', 'capital': 'Phnom Penh'},
{'timezones': ['Africa/Bangui'], 'code': 'CF', 'continent': 'Africa', 'name': 'Central African Republic', 'capital': 'Bangui'},
{'timezones': ['Africa/Ndjamena'], 'code': 'TD', 'continent': 'Africa', 'name': 'Chad', 'capital': "N'Djamena"},
{'timezones': ['Indian/Comoro'], 'code': 'KM', 'continent': 'Africa', 'name': 'Comoros', 'capital': 'Moroni'},
{'timezones': ['Europe/Zagreb'], 'code': 'HR', 'continent': 'Europe', 'name': 'Croatia', 'capital': 'Zagreb'},
{'timezones': ['Asia/Dili'], 'code': 'TL', 'continent': 'Asia', 'name': 'East Timor', 'capital': 'Dili'},
{'timezones': ['America/El_Salvador'], 'code': 'SV', 'continent': 'North America', 'name': 'El Salvador', 'capital': 'San Salvador'},
{'timezones': ['Africa/Malabo'], 'code': 'GQ', 'continent': 'Africa', 'name': 'Equatorial Guinea', 'capital': 'Malabo'},
{'timezones': ['America/Grenada'], 'code': 'GD', 'continent': 'North America', 'name': 'Grenada', 'capital': "St. George's"},
{'timezones': ['Asia/Almaty', 'Asia/Qyzylorda', 'Asia/Aqtobe', 'Asia/Aqtau', 'Asia/Oral'], 'code': 'KZ', 'continent': 'Asia', 'name': 'Kazakhstan', 'capital': 'Astana'},
{'timezones': ['Asia/Vientiane'], 'code': 'LA', 'continent': 'Asia', 'name': 'Laos', 'capital': 'Vientiane'},
{'timezones': ['Pacific/Truk', 'Pacific/Ponape', 'Pacific/Kosrae'], 'code': 'FM', 'continent': 'Oceania', 'name': 'Federated States of Micronesia', 'capital': 'Palikir'},
{'timezones': ['Europe/Chisinau'], 'code': 'MD', 'continent': 'Europe', 'name': 'Moldova', 'capital': 'Chi\xc5\x9fin\xc4\x83u'},
{'timezones': ['Europe/Monaco'], 'code': 'MC', 'continent': 'Europe', 'name': 'Monaco', 'capital': 'Monaco'},
{'timezones': ['Europe/Podgorica'], 'code': 'ME', 'continent': 'Europe', 'name': 'Montenegro', 'capital': 'Podgorica'},
{'timezones': ['Africa/Casablanca'], 'code': 'MA', 'continent': 'Africa', 'name': 'Morocco', 'capital': 'Rabat'},
{'timezones': ['America/St_Kitts'], 'code': 'KN', 'continent': 'North America', 'name': 'Saint Kitts and Nevis', 'capital': 'Basseterre'},
{'timezones': ['America/St_Lucia'], 'code': 'LC', 'continent': 'North America', 'name': 'Saint Lucia', 'capital': 'Castries'},
{'timezones': ['America/St_Vincent'], 'code': 'VC', 'continent': 'North America', 'name': 'Saint Vincent and the Grenadines', 'capital': 'Kingstown'},
{'timezones': ['Pacific/Apia'], 'code': 'WS', 'continent': 'Oceania', 'name': 'Samoa', 'capital': 'Apia'},
{'timezones': ['Europe/Belgrade'], 'code': 'RS', 'continent': 'Europe', 'name': 'Serbia', 'capital': 'Belgrade'},
{'timezones': ['Africa/Johannesburg'], 'code': 'ZA', 'continent': 'Africa', 'name': 'South Africa', 'capital': 'Pretoria'},
{'timezones': ['Europe/Madrid', 'Africa/Ceuta', 'Atlantic/Canary'], 'code': 'ES', 'continent': 'Europe', 'name': 'Spain', 'capital': 'Madrid'},
{'timezones': ['Asia/Colombo'], 'code': 'LK', 'continent': 'Asia', 'name': 'Sri Lanka', 'capital': 'Sri Jayewardenepura Kotte'},
{'timezones': ['Africa/Mbabane'], 'code': 'SZ', 'continent': 'Africa', 'name': 'Swaziland', 'capital': 'Mbabane'},
{'timezones': ['Europe/Zurich'], 'code': 'CH', 'continent': 'Europe', 'name': 'Switzerland', 'capital': 'Bern'},
{'timezones': ['Asia/Dubai'], 'code': 'AE', 'continent': 'Asia', 'name': 'United Arab Emirates', 'capital': 'Abu Dhabi'},
{'timezones': ['Europe/London'], 'code': 'GB', 'continent': 'Europe', 'name': 'United Kingdom', 'capital': 'London'},
{'timezones': ['Asia/Taipei'], 'code': 'TW', 'continent': 'Asia', 'name': 'Taiwan', 'capital': 'Taipei'},
{'timezones': ['Asia/Hong_Kong'], 'code': 'HK', 'continent': 'Asia', 'name': 'Hong Kong', 'capital': 'Hong Kong'},
{'timezones': ['CET'], 'code': 'XK', 'continent': 'Europe', 'name': 'Kosovo', 'capital': 'Pristina'},
{'timezones': ['America/Puerto_Rico'], 'code': 'PR', 'continent': 'America', 'name': 'Puerto Rico', 'capital': 'San Juan'},
]

# %%
import matplotlib.pyplot as plt, numpy as np
from mpl_toolkits.mplot3d import proj3d
from scipy.spatial.distance import pdist, squareform
from sklearn import manifold
from sklearn.metrics import euclidean_distances
from sklearn.decomposition import PCA
import math
from sklearn.preprocessing import normalize
from scipy.spatial.distance import squareform,pdist
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt2
import numpy as np
import csv
import  pandas  as pd
from  sklearn.cluster  import  DBSCAN
from  geopy.distance  import  great_circle
from  shapely.geometry  import  MultiPoint
import matplotlib.pyplot as plt
from time import time
import io
from sklearn.manifold import Isomap
from sklearn.manifold import TSNE
from sklearn.datasets import load_digits
from sklearn.manifold import LocallyLinearEmbedding
from sklearn.manifold import MDS
from sklearn.manifold import SpectralEmbedding
from haversine import haversine
from vincenty import vincenty
import warnings; warnings.simplefilter('ignore')


def fix_table(A):
    for i in range(len(A)):
        for j in range(len(A)):
                A[i,j]=A[j,i]
                #print(i,j,A[i,j],A[j,i])
def check_sym(A):
    if check_symmetric(A) is False:
        fix_table(A)
def euclidean_distances2(A):
    kart=euclidean_distances(A)
    check_sym(kart)
    return kart
def fix_table2(A):
    for i in range(len(A)):
        for j in range(len(A)):
            d=int((A[i,j]-A[j,i])*10000)/1000
            if d!=0:
                #print(i,j,A[i,j],A[j,i])
                A[i,j]=A[j,i]
                #print(i,j,A[i,j],A[j,i])
    
def check_symmetric(a, tol=1e-8):
    return np.allclose(a, a.T, atol=tol)
def myplotM(mylats1,mylons1):    
    # %matplotlib qt
    zoom_scale = 0

    # Setup the bounding box for the zoom and bounds of the map
    bbox = [np.min(mylats1)-zoom_scale,np.max(mylats1)+zoom_scale,\
            np.min(mylons1)-zoom_scale,np.max(mylons1)+zoom_scale]

    plt.figure(figsize=(12,6))
    # Define the projection, scale, the corners of the map, and the resolution.
    m = Basemap(projection='merc',llcrnrlat=bbox[0],urcrnrlat=bbox[1],\
                llcrnrlon=bbox[2],urcrnrlon=bbox[3],lat_ts=10,resolution='i')

    # Draw coastlines and fill continents and water with color
    m.drawcoastlines()
    m.fillcontinents(color='blue',lake_color='dodgerblue')

    # draw parallels, meridians, and color boundaries
    m.drawparallels(np.arange(bbox[0],bbox[1],(bbox[1]-bbox[0])/5),labels=[1,0,0,0])
    m.drawmeridians(np.arange(bbox[2],bbox[3],(bbox[3]-bbox[2])/5),labels=[0,0,0,1],rotation=45)
    m.drawmapboundary(fill_color='dodgerblue')

    # build and plot coordinates onto map
    x,y = m(mylons1,mylats1)
    xMerc=x
    yMerx=y
    m.plot(x,y,'r*',markersize=3)
    plt.title("Pre clustered data")
    plt.savefig('gr_sub.png', format='png', dpi=500)
    plt.show()
def p2cart():
    fdata21  =np.array(lon_lat_to_cartesian2(mylats,mylons),dtype=np.float32)
    fdata21=np.transpose(fdata21)
    return fdata21
def lon_lat_to_cartesian2(lat, lon):
    import numpy as np
    import numpy as Math
    import math 
    pi=math.pi
    
    lon=np.array(lon,dtype=np.float32)
    lat=np.array(lat,dtype=np.float32)
    
    cosLat = Math.cos(lat * pi / 180.0)
    sinLat = Math.sin(lat * pi / 180.0)
    cosLon = Math.cos(lon * pi / 180.0)
    sinLon = Math.sin(lon * pi / 180.0)
    
    """
    calculates lon, lat coordinates of a point on a sphere with
    radius R
    """
    lon=np.array(lon,dtype=np.float32)
    lat=np.array(lat,dtype=np.float32)
    rad = 6378137.0
    f = 1.0 / 298.257224
    C = 1.0 / Math.sqrt(cosLat * cosLat + (1 - f) * (1 - f) * sinLat * sinLat)
    S = (1.0 - f) * (1.0 - f) * C
    h = 0.0;
    x = (rad * C + h) * cosLat * cosLon
    y = (rad * C + h) * cosLat * sinLon
    z = (rad * S + h) * sinLat
    print(x,y,z)
    return [x,y,z]
def cart_to_ll(xy):
    R1 = 6378100
    xy=np.array(xy,dtype=np.float32)
    x=xy[:,1]
    y=xy[:,0]
    #(x, y, z) = xy # does not use `z`
    r = np.sqrt(x**2 + y**2)/R1
    long =np.array(180 * np.arctan2(y,x)/math.pi,dtype=np.float32)
    lat = 180 *np.arccos(r)/math.pi
    return np.transpose(np.array((lat,long),dtype=np.float32))
def Merc(mylats1, mylons1):
    import numpy as np
    import numpy as Math
    import math 
    pi=math.pi
    
     
    
    
    mylons1=np.array(mylons1,dtype=np.float32)
    mylats1=np.array(mylats1,dtype=np.float32)
    
    bbox = [np.min(mylats1)-zoom_scale,np.max(mylats1)+zoom_scale,\
            np.min(mylons1)-zoom_scale,np.max(mylons1)+zoom_scale]

    #plt.figure(figsize=(12,6))
    # Define the projection, scale, the corners of the map, and the resolution.
    m = Basemap(projection='merc',llcrnrlat=bbox[0],urcrnrlat=bbox[1],\
                llcrnrlon=bbox[2],urcrnrlon=bbox[3],lat_ts=10,resolution='i')

    # Draw coastlines and fill continents and water with color
    m.drawcoastlines()
    m.fillcontinents(color='blue',lake_color='dodgerblue')

    # draw parallels, meridians, and color boundaries
    m.drawparallels(np.arange(bbox[0],bbox[1],(bbox[1]-bbox[0])/5),labels=[1,0,0,0])
    m.drawmeridians(np.arange(bbox[2],bbox[3],(bbox[3]-bbox[2])/5),labels=[0,0,0,1],rotation=45)
    m.drawmapboundary(fill_color='dodgerblue')

    # build and plot coordinates onto map
    x,y = m(mylons1,mylats1)
    xMerc=x
    yMerx=y
    print(xMerc,yMerx)
    return [xMerc,yMerx]
def haversine2(u,v,d):
    dis=haversine(u,v)
    if dis<=d:
        return dis
    else:
        return 0
def fill_color2(X,d=3):
    import collections
    import math
    import matplotlib.colors as mcolors
    colors2=mcolors.CSS4_COLORS
    by_hsv = ((tuple(mcolors.rgb_to_hsv(mcolors.to_rgba(color)[:3])), name)
                        for name, color in colors2.items())

    by_hsv = sorted(by_hsv)
    cnames = [name for hsv, name in by_hsv]
    cnm=len(cnames)
    color=[]
    if d==17:
        cco=list(collections.Counter(X[:,d]))
        len(cco)

        cld={}
        
        for cf in cco:
            
            if cf=='Africa':
                n='lime'
            if cf=='America':
                n='red'
            if cf=='Arctic':
                n='gray'
            if cf=='Asia':
                n='gold'
            if cf=='Atlantic':
                n='cyan'
            if cf=='Australia':
                n='g'
              
            if cf=='Europe':
                n='blue'
            if cf=='Indian':
                n='peru'
            if cf=='Pacific':
                n='cyan'
            
                
            cld[cf]=n
         
      

        for l in X[:,d]:
            color.append(cld[l])
        
    else:
        color=[]
        cco=list(collections.Counter(X[:,d]))
        len(cco)
        
        cld={}
        n=1
        for cf in cco:
            
            cld[cf]=cnames[n]
            n+=2
            if n>=cnm:
                n=1

        for l in X[:,d]:
            color.append(cld[l])
    return color

# {'Africa',
#  'America',
#  'Arctic',
#  'Asia',
#  'Atlantic',
#  'Australia',
#  'Europe',
#  'Indian',
#  'Pacific'}


def visualize3DData (X,title):
    """Visualize data in 3d plot with popover next to mouse position.

    Args:
        X (np.array) - array of points, of shape (numPoints, 3)
    Returns:
        None
    """
   
    fig = plt.figure(figsize = (16,10))
    ax = fig.add_subplot(111, projection = '3d')
    ax.scatter(X[:, 6], X[:, 7], X[:, 8], depthshade = False, c=color, picker = True,s=10)
    plt.gcf().canvas.set_window_title(title)

    def distance(p1,p2,p3, event):
        """Return distance between mouse position and given data point

        Args:
            point (np.array): np.array of shape (3,), with x,y,z in data coords
            event (MouseEvent): mouse event (which contains mouse position in .x and .xdata)
        Returns:
            distance (np.float64): distance (in screen coords) between mouse pos and data point
        """
        point=np.array([p1,p2,p3])
        assert point.shape == (3,), "distance: point.shape is wrong: %s, must be (3,)" % point.shape

        # Project 3d data space to 2d data space
        x2, y2, _ = proj3d.proj_transform(point[0], point[1], point[2], plt.gca().get_proj())
        # Convert 2d data space to 2d screen space
        x3, y3 = ax.transData.transform((x2, y2))

        return np.sqrt ((x3 - event.x)**2 + (y3 - event.y)**2)


    def calcClosestDatapoint(X, event):
        """"Calculate which data point is closest to the mouse position.

        Args:
            X (np.array) - array of points, of shape (numPoints, 3)
            event (MouseEvent) - mouse event (containing mouse position)
        Returns:
            smallestIndex (int) - the index (into the array of points X) of the element closest to the mouse position
        """
        distances = [distance (X[i, 6],X[i, 7],0, event) for i in range(X.shape[0])]
        return np.argmin(distances)


    def annotatePlot(X, index):
        """Create popover label in 3d chart

        Args:
            X (np.array) - array of points, of shape (numPoints, 3)
            index (int) - index (into points array X) of item which should be printed
        Returns:
            None
        """
        # If we have previously displayed another label, remove it first
        if hasattr(annotatePlot, 'label'):
            annotatePlot.label.remove()
        # Get data point from array of points X, at position index
        x2, y2, z2 = proj3d.proj_transform(X[index, 6], X[index, 7], X[index, 8], ax.get_proj())
        annotatePlot.label = plt.annotate( "{}:\n{},{}\n{},{}\n{} {}".format(X[index, 2],X[index, 0], X[index, 1],X[index, 6], X[index, 7], X[index, 3]+'-'+X[index, 5], X[index, 4]) ,
            xy = (x2, y2), xytext = (-20, 20), textcoords = 'offset points', ha = 'right', va = 'bottom',
            bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.8),
            arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))
        fig.canvas.draw()

def visualize2DData (X,title,d=3,col='midnight'):
    """Visualize data in 3d plot with popover next to mouse position.

    Args:
        X (np.array) - array of points, of shape (numPoints, 3)
    Returns:
        None
    """
    
    color=fill_color(X,d)
    
#     import collections


#     cco=list(collections.Counter(X[:,d]))
#     len(cco)

#     cld={}
#     n=1
#     for cf in cco:
#         cld[cf]=n
#         n+=200
#     color=[]
#     for l in X[:,d]:
#         color.append(cld[l])
    fig = plt.figure(figsize = (16,10))
    ax = fig.add_subplot(111, projection = '3d')
    ax.scatter(X[:, 6], X[:, 7], X[:, 6]*0, depthshade = False, c=color, picker = True,s=10)
    ax.set_facecolor('xkcd:'+col)
    plt.gcf().canvas.set_window_title(title)

    def distance(p1,p2,p3, event):
        """Return distance between mouse position and given data point

        Args:
            point (np.array): np.array of shape (3,), with x,y,z in data coords
            event (MouseEvent): mouse event (which contains mouse position in .x and .xdata)
        Returns:
            distance (np.float64): distance (in screen coords) between mouse pos and data point
        """
        point=np.array([p1,p2,p3])
        assert point.shape == (3,), "distance: point.shape is wrong: %s, must be (3,)" % point.shape

        # Project 3d data space to 2d data space
        x2, y2, _ = proj3d.proj_transform(point[0], point[1], point[2], plt.gca().get_proj())
        # Convert 2d data space to 2d screen space
        x3, y3 = ax.transData.transform((x2, y2))

        return np.sqrt ((x3 - event.x)**2 + (y3 - event.y)**2)


    def calcClosestDatapoint(X, event):
        """"Calculate which data point is closest to the mouse position.

        Args:
            X (np.array) - array of points, of shape (numPoints, 3)
            event (MouseEvent) - mouse event (containing mouse position)
        Returns:
            smallestIndex (int) - the index (into the array of points X) of the element closest to the mouse position
        """
        distances = [distance (X[i, 6],X[i, 7],0, event) for i in range(X.shape[0])]
        return np.argmin(distances)


    def annotatePlot(X, index):
        """Create popover label in 3d chart

        Args:
            X (np.array) - array of points, of shape (numPoints, 3)
            index (int) - index (into points array X) of item which should be printed
        Returns:
            None
        """
        # If we have previously displayed another label, remove it first
        if hasattr(annotatePlot, 'label'):
            annotatePlot.label.remove()
        # Get data point from array of points X, at position index
        x2, y2, _ = proj3d.proj_transform(X[index, 6], X[index, 7], X[index, 6]*0, ax.get_proj())
        annotatePlot.label = plt.annotate( "{}:\n{},{}\n{},{}\n{} {}".format(X[index, 2],X[index, 0], X[index, 1],X[index, 6], X[index, 7], X[index, 3]+'-'+X[index, 5], X[index, 4]) ,
            xy = (x2, y2), xytext = (-20, 20), textcoords = 'offset points', ha = 'right', va = 'bottom',
            bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.8),
            arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))
        fig.canvas.draw()


    def onMouseMotion(event):
        """Event that is triggered when mouse is moved. Shows text annotation over data point closest to mouse."""
        closestIndex = calcClosestDatapoint(X, event)
        annotatePlot (X, closestIndex)

    fig.canvas.mpl_connect('motion_notify_event', onMouseMotion)  # on mouse motion
    plt.show()
def find_error(p1,p2,X,debug):
    from scipy.spatial import distance
    import math
       
    fd1=euclidean_distances([X[p1,5:7],X[p2,5:7]])[0,1]  
    d1=euclidean_distances([X[p1,0:2],X[p2,0:2]])[0,1]
                 
    
    Dd=abs(fd1-d1)
    if debug:
        print("Start:",X[p1,3],X[p1,2])
        print(X[p1,0],",",X[p1,1])
        print("End:",X[p2,3],X[p2,2])
        print(X[p2,0],",",X[p2,1])
        print("dist:",fd1,",",d1)
        print(X[p1,5],X[p1,6],X[p2,5],X[p2,6])
        print(X[p1,0],X[p1,1],X[p2,0],X[p2,1])
    return (fd1-d1)**2,d1**2
def check_result(cou,P,debug):
    a=0
    b=0
    asum=0
    bsum=0
    from random import randint

    for i in range(0,len(P)):
        #print("step:",i)
        for j in range(0,len(P)):
                a,b=find_error(i,j,P,debug)
                asum+=a
                bsum+=b
    print("Stress ",math.sqrt(asum/bsum))
def  get_centermost_point(cluster):
    centroid = (MultiPoint(cluster).centroid.x, MultiPoint(cluster).centroid.y)
    centermost_point = min(cluster , key=lambda  point: great_circle(point , centroid).m)
    return  tuple(centermost_point)


def ccluster(coor,ep):  
    print ("ccluster",len(coor))
    kms_per_radian = 6371.0088
    epsilon = ep/ kms_per_radian
    db = DBSCAN(eps=epsilon ,
    min_samples =1,
    algorithm='ball_tree',
    metric='haversine').fit(np.radians(coor[:,0:2]))
    cluster_labels = db.labels_
    num_clusters = len(set(cluster_labels))
    clusters = pd.Series ([ coor[cluster_labels  == n] for n in  range(num_clusters)])
    print('Number  of  clusters: {}'.format(num_clusters))
    #print(clusters[0:3])
    centermost_points = clusters.map(get_centermost_point)
    #print ("cpoints",centermost_points)
    return centermost_points
def start_cluster(coo ,st,minp):    

    cpoints=ccluster(coo,st)
    print(len(cpoints))
    lats , lons ,geoid = zip(* cpoints)
    rep_point = pd.DataFrame ({  'lat':lats,'lon':lons, 'geoid':geoid})
    print(len(rep_point))
    mycities2=rep_point.values

    cpoints=ccluster(mycities2,2*st)
    print(len(cpoints))
    lats , lons ,geoid = zip(* cpoints)
    rep_point = pd.DataFrame ({  'lat':lats,'lon':lons, 'geoid':geoid})
  
    
    if len(cpoints)>minp:
        mycities2=rep_point.values
        cpoints=ccluster(mycities2,4*st)
        print(len(cpoints))
        lats , lons ,geoid = zip(* cpoints)
        rep_point = pd.DataFrame ({  'lat':lats,'lon':lons, 'geoid':geoid})
   
    if len(cpoints)>minp:
        mycities2=rep_point.values
        cpoints=ccluster(mycities2,6*st)
        print(len(cpoints))
        lats , lons ,geoid = zip(* cpoints)
        rep_point = pd.DataFrame ({  'lat':lats,'lon':lons, 'geoid':geoid})
    
    if len(cpoints)>minp:
        mycities2=rep_point.values
        cpoints=ccluster(mycities2,8*st)
        print(len(cpoints))
        lats , lons ,geoid = zip(* cpoints)
        rep_point = pd.DataFrame ({  'lat':lats,'lon':lons, 'geoid':geoid})
   
    if len(cpoints)>minp:
        mycities2=rep_point.values
        cpoints=ccluster(mycities2,10*st)
        print(len(cpoints))
        lats , lons ,geoid = zip(* cpoints)
        rep_point = pd.DataFrame ({  'lat':lats,'lon':lons, 'geoid':geoid})
   
    if len(cpoints)>minp:
        mycities2=rep_point.values
        cpoints=ccluster(mycities2,12*st)
        print(len(cpoints))
        lats , lons ,geoid = zip(* cpoints)
    
    if len(cpoints)>minp:
        mycities2=rep_point.values
        cpoints=ccluster(mycities2,15*st)
        print(len(cpoints))
        lats , lons ,geoid = zip(* cpoints)
    rnum=len(geoid)
    rr=([df[df[0]==geoid[n]].as_matrix(columns =[2,17,8,18,19,20]) for n in  range(len(geoid))])
    rr1=[]
    rr3=[]
    rr4=[]
    
    for  o in rr:
        rr1.append(o[0][0])
        rr3.append(o[0][1])
        rr4.append(o[0][2])
        rr5.append(o[0][3])
        rr6.append(o[0][4])
        rr7.append(o[0][5])
        
    #rr2=pd.Series([df[df[0]==geoid[n]][8] for n in  range(len(geoid))])
    #rr2=([df[df[0]==geoid[n]].as_matrix(columns =[8])[0] for n in  range(len(geoid))]) 
    #rr2=rr2.iloc[:]
       
         
    rep_point = pd.DataFrame ({  'lat':lats,'lon':lons, 'name':rr1,'country':rr3, 'geoid':geoid,'cont':rr4,'x': rr5, 'y':rr6, 'z':rr7  })
    return rep_point
def myplot(mylats1,mylons1,myz=0): 
 
    from matplotlib import pyplot
    from mpl_toolkits.mplot3d import Axes3D
    fig = pyplot.figure()
    ax = Axes3D(fig)
    ax.scatter(mylats1, mylons1, myz)
    pyplot.show()
def plotmap(coords):
    lats=coords[:,0]
    lons=coords[:,1]
    gid=coords[:,2]
  
    zoom_scale = 0
    # Setup the bounding box for the zoom and bounds of the map
    bbox = [np.min(lats)-zoom_scale,np.max(lats)+zoom_scale,\
            np.min(lons)-zoom_scale,np.max(lons)+zoom_scale]
    plt.figure(figsize=(12,6))
    # Define the projection, scale, the corners of the map, and the resolution.
    m = Basemap(projection='merc',llcrnrlat=bbox[0],urcrnrlat=bbox[1],\
                llcrnrlon=bbox[2],urcrnrlon=bbox[3],lat_ts=10,resolution='i')

    x,y = m(lons,lats)
    m.plot(x,y,'r*',markersize=3)
    m.bluemarble()
    
    plt.savefig('mtitle.png', format='png', dpi=500)
    plt.show()
    return xyMerc
def plotmap2(coords,mtitle):
    lats=coords[:,0]
    lons=coords[:,1]
    gid=coords[:,2]
    #coords = df.as_matrix(columns =['LAT','LON','ELEV'])        
    # How much to zoom from coordinates (in degrees)
    zoom_scale = 0
    # Setup the bounding box for the zoom and bounds of the map
    bbox = [np.min(lats)-zoom_scale,np.max(lats)+zoom_scale,\
            np.min(lons)-zoom_scale,np.max(lons)+zoom_scale]
    #plt.figure(figsize=(12,6))
    # Define the projection, scale, the corners of the map, and the resolution.
    m = Basemap(projection='merc',llcrnrlat=bbox[0],urcrnrlat=bbox[1],\
                llcrnrlon=bbox[2],urcrnrlon=bbox[3],lat_ts=10,resolution='i')
    # Draw coastlines and fill continents and water with color
    #m.drawcoastlines()
    #m.fillcontinents(color='blue',lake_color='dodgerblue')
    # draw parallels, meridians, and color boundaries
    #m.drawparallels(np.arange(bbox[0],bbox[1],(bbox[1]-bbox[0])/5),labels=[1,0,0,0])
    #m.drawmeridians(np.arange(bbox[2],bbox[3],(bbox[3]-bbox[2])/5),labels=[0,0,0,1],rotation=45)
    #m.drawmapboundary(fill_color='dodgerblue')
    # build and plot coordinates onto map
    x,y = m(lons,lats)
    #m.plot(x,y,'r*',markersize=3)
    xMerc=np.array(x,dtype=np.float32)
    yMerc=np.array(y,dtype=np.float32)
    xyMerc=np.array([xMerc,yMerc],dtype=np.float32)
    #plt.title(mtitle)
    #plt.savefig('mtitle', format='png', dpi=500)
    #plt.show()
    m=None
    return xyMerc
def res_check(mult=10000):
    from random import randint
    import scipy
    pl1=randint(0, len(mycitiesFD2)-1)
    pl2=randint(0, len(mycitiesFD2)-1)
    dpl1=mycitiesc[pl1]
    dpl2=mycitiesc[pl2]
    id1=mycitiesc[pl1,4]
    id2=mycitiesc[pl2,4]
    n1=df[df[0]==id1].as_matrix(columns =[2])+'-'+df[df[0]==id1].as_matrix(columns =[8])
    name1=str(n1[0][0])
    n2=df[df[0]==id2].as_matrix(columns =[2])+'-'+df[df[0]==id2].as_matrix(columns =[8])
    name2=str(n2[0][0])
    h1=dpl1[0:2]
    h2=dpl2[0:2]
    c1=dpl1[-3:]
    c2=dpl2[-3:]
    DisH=haversine(h1,h2)
    DisC=scipy.spatial.distance.euclidean(c1,c2)/mult
    meth11=mycitiesFD[pl1]
    meth12=mycitiesFD[pl2]
    m1c1=meth11[-2:]
    m1c2=meth12[-2:]
    DisM1=scipy.spatial.distance.euclidean(m1c1,m1c2)

    meth21=mycitiesFn[pl1]
    meth22=mycitiesFn[pl2]
    m2c1=meth21[-2:]
    m2c2=meth22[-2:]
    DisM2=scipy.spatial.distance.euclidean(m2c1,m2c2)*100

    meth31=mycitiesFn2[pl1]
    meth32=mycitiesFn2[pl2]
    m3c1=meth31[-2:]
    m3c2=meth32[-2:]
    DisM3=scipy.spatial.distance.euclidean(m3c1,m3c2)

    meth41=mycitiesFn7[pl1]
    meth42=mycitiesFn7[pl2]
    m4c1=meth41[-2:]
    m4c2=meth42[-2:]
    DisM4=scipy.spatial.distance.euclidean(m4c1,m4c2)/1000

    #print(name1,id1,h1,c1,name2,id2,h2,c2)
    return name1,h1,name2,h2,DisH,DisC,DisM1,DisM2,DisM3,DisM4,c1, c2
def cont(country):
    country=[num for num in countries if num['code'] ==country]
    return country[0]['continent']

def merc_ll(lats, lons):
    r_major = 6378137.000
    x = r_major * np.radians(lon)
    scale = x/lon
    y = 180.0/np.pi * np.log(np.tan(np.pi/4.0 + lat * (np.pi/180.0)/2.0)) * scale
    return np.array(x, y)



    #TEST
def test(ns):    
    from random import randint
    t0=time()
    sDisH=0
    sDisC=0
    sDisM1=0
    sDisM2=0
    sDisM3=0
    sDisM4=0
    kh=0
    kc=0
    km1=0
    km2=0
    km3=0
    km4=0
    pDisH=0
    pDisC=0
    pDisM1=0
    pDisM2=0
    pDisM3=0
    pDisM4=0
    n=int(len(fdata2)/1)
    pr=False

    if ns==2:
        n=2
        pr=True

    for i in range(n):
        name1,h1,name2,h2,DisH,DisC,DisM1,DisM2,DisM3,DisM4,c1,c2=res_check(1000)

        if DisH!=0:

            kh=kh+pDisH/DisH
            kc=kc+pDisC/DisC
            km1=km1+pDisM1/DisM1
            km2=km2+pDisM2/DisM2
            km3=km3+pDisM3/DisM3
            km4=km4+pDisM4/DisM4

        sDisH+=DisH
        sDisC+=DisC
        sDisM1+=DisM1
        sDisM2+=DisM2
        sDisM3+=DisM3
        sDisM4+=DisM4
        pDisH=DisH
        pDisC=DisC
        pDisM1=DisM1
        pDisM2=DisM2
        pDisM3=DisM3
        pDisM4=DisM4

        if pr==True:
            print(name1,'|',h1,'|',c1,'|')
            print(name2,'|',h2,'|',c2,'|')
            print('|H:',DisH,'|Euc:',DisC,'|M1:',DisM1,'|M2:',DisM4,'|M3:',DisM2)
            print('|rH:',kh,'|rEuc:',kc,'|rM1:',km1,'|rM2:',km4,'|rM3:',km2)
            print('--------------------------------------------------------------------------')

    khf=kh/(n-1)
    kcf=kc/(n-1)
    km1f=km1/(n-1)
    km2f=km2/(n-1)
    km3f=km3/(n-1)
    km4f=km4/(n-1)
    print("M3 NMDS HAVERSINE DISTANCE")
    print("M2 MDS CARTESIAN - EUCLEDIAN DISTANCE")
    print("M1 MDS HAVERSINE  DISTANCE")
    print("Number of Distances checked:",n)
    print('|SH:',sDisH,'|SEuc:',sDisC,'|SM1:',sDisM1,'|SM2:',sDisM4)
    #print('|mH:',khf,'|mEuc:',kcf,'|mM1:',km1f,'|mM2',km2f,'|mM3:',km4f)
    print('|eH:',0,'|eEuc:',abs(sDisC-sDisH),'|eM1:',abs(sDisM1-sDisH),'|eM2:',abs(sDisM4-sDisH))
    print('|eH:',1,'|eEuc:',100*abs(sDisC-sDisH)/sDisH,'|eM1:',100*abs(sDisM1-sDisH)/sDisH,'|eM2:',100*abs(sDisM4-sDisH)/sDisH)
    print("Time min: " ,(time()-t0)/60)

# %%
import matplotlib.pyplot as plt, numpy as np
from mpl_toolkits.mplot3d import proj3d
from scipy.spatial.distance import pdist, squareform
from sklearn import manifold
from sklearn.metrics import euclidean_distances
from sklearn.decomposition import PCA
import math
from sklearn.preprocessing import normalize
from scipy.spatial.distance import squareform,pdist
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt2
import numpy as np
import csv
import  pandas  as pd
from  sklearn.cluster  import  DBSCAN
from  geopy.distance  import  great_circle
from  shapely.geometry  import  MultiPoint
import matplotlib.pyplot as plt
from time import time
import io
from sklearn.manifold import Isomap
from sklearn.manifold import TSNE
from sklearn.datasets import load_digits
from sklearn.manifold import LocallyLinearEmbedding
from sklearn.manifold import MDS
from sklearn.manifold import SpectralEmbedding
from haversine import haversine
from vincenty import vincenty
import warnings; warnings.simplefilter('ignore')
from  helpers import *

# %%
#IMPORT DATA FROM FILES
lats, lons,names,elev = [],[],[],[]
df = pd.read_csv('all.txt',sep='\t',header=None)
print(df.shape)
df[17]=df[17].str.split('/').str[0]
df = df[df[6]=='P']
df = df[df[8].notnull()]
print(df.shape)
# Out:
# (11857704, 19)
# (4708904, 19)

# %%
# %matplotlib qt
rad = 6378137.0
radk=rad/1000
#coordA = df.as_matrix(columns =[4,5,0]) 
coordA = df[[4,5,0]].to_numpy()
latA=coordA[:,0]
lonsA=coordA[:,1]
fdataA=p2cart(latA,lonsA);
fdataA[:,0]=fdataA[:,0]-fdataA[:,0].min()
fdataA[:,1]=fdataA[:,1]-fdataA[:,1].min()
fdataA[:,2]=fdataA[:,2]-fdataA[:,2].min()
fdataA[:,0]=fdataA[:,0]/fdataA[:,0].max()
fdataA[:,1]=fdataA[:,1]/fdataA[:,1].max()
fdataA[:,2]=fdataA[:,2]/fdataA[:,2].max()
myplot(fdataA[:,0],fdataA[:,1],fdataA[:,2])

# %%
fdataA.shape,df.shape
df[18]=fdataA[:,0]
df[19]=fdataA[:,1]
df[20]=fdataA[:,2]
df
# Out:
#                 0                     1                     2   \
# 10         3038816             Xixerella             Xixerella
# 25         3038832                  Vila                  Vila
# 92         3038899    Tossalet i Vinyals    Tossalet i Vinyals
# 180        3038987                Sornàs                Sornas
# 192        3038999                Soldeu                Soldeu
# ...            ...                   ...                   ...
# 11851805  11523318             Siamwanja             Siamwanja
# 11851809  11523329  Mutekairi Dangamvura  Mutekairi Dangamvura
# 11851811  11523382         Bexley Circle         Bexley Circle
# 11851812  11523383        Montagu Centre        Montagu Centre
# 11851825  11822469       Mhombera Estate       Mhombera Estate
#
#                           3         4         5  6     7   8    9   ...   11  \
# 10                       NaN  42.55327   1.48736  P   PPL  AD  NaN  ...  NaN
# ...

# %%
# latA=[-180,180]
# lonsA=[-89,89]
# fda=p2cart(latA,lonsA);
# # fda[:,0]=fda[:,0]-fda[:,0].min()
# # fda[:,1]=fda[:,1]-fda[:,1].min()
# # fda[:,2]=fda[:,2]-fda[:,2].min()
# # fda[:,0]=fda[:,0]/fda[:,0].max()
# # fda[:,1]=fda[:,1]/fda[:,1].max()
# # fda[:,2]=fda[:,2]/fda[:,2].max()
# myplot(fda[:,0],fda[:,1],fda[:,2])
# print(fda[:,0].min(),fda[:,1].min(),fda[:,2].min())
# print(fda[:,0].max(),fda[:,1].max(),fda[:,2].max())

# %%
# latA=coordA[:,0]
# lonsA=coordA[:,1]
# fda=p2cart(latA,lonsA);
# # fda[:,0]=fda[:,0]-fda[:,0].min()
# # fda[:,1]=fda[:,1]-fda[:,1].min()
# # fda[:,2]=fda[:,2]-fda[:,2].min()
# # fda[:,0]=fda[:,0]/fda[:,0].max()
# # fda[:,1]=fda[:,1]/fda[:,1].max()
# # fda[:,2]=fda[:,2]/fda[:,2].max()
# myplot(fda[:,0],fda[:,1],fda[:,2])
# print(fda[:,0].min(),fda[:,1].min(),fda[:,2].min())
# print(fda[:,0].max(),fda[:,1].max(),fda[:,2].max())

# %%
#earth
lat=0
lon=0
zoom_lat=178 #(0,180)
zoom_lon=358 #(0,360)
pref='earth_'

# #poles
# lat=89
# lon=0
# zoom_lat=178 #(0,180)
# zoom_lon=358 #(0,360)
# pref='poles_'

# #Africa
# lat=8.6
# lon=21.70
# zoom_lat=60 #(0,180)
# zoom_lon=80 #(0,360)
# pref='afrika_'

# #Greek World
# lat=38.70
# lon=22.40
# zoom_lat=28 #(0,180)
# zoom_lon=24 #(0,360)


# #earth AU 
# lat=-25
# lon=140
# zoom_lat=60 #(0,180)
# zoom_lon=80 #(0,360)
# pref='AU_'


# #earth china2
# lat=0
# lon=116
# zoom_lat=178 #(0,180)
# zoom_lon=358 #(0,360)
# pref='china2_'

# #earth china
# lat=39
# lon=116
# zoom_lat=178 #(0,180)
# zoom_lon=358 #(0,360)
# pref='china_'

# #europe
# lat=50
# lon=10
# zoom_lat=30 #(0,180)
# zoom_lon=40 #(0,360)
# pref='euro1_'

# #USA
# lat=40
# lon=-96
# zoom_lat=26 #(0,180)
# zoom_lon=60 #(0,360)
# pref='USA_'


# #USA
# lat=0
# lon=-100
# zoom_lat=120 #(0,180)
# zoom_lon=150 #(0,360)
# pref='americas_'


# %matplotlib qt

# %%
df12=df.copy()

# %%
df12.shape
# Out:
# (4708904, 21)

# %%
df12=df12[df12[8]=='GR']
df12.shape
# Out:
# (14969, 21)

# %%
#grcoords = df12.as_matrix(columns =[4,5,0]) 
#grcoordp = df12.as_matrix(columns =[18,19,20]) 

grcoords = df12[[4,5,0]].to_numpy()
grcoordp = df12[[18,19,20]].to_numpy()

# %%
Xfdatagr=np.array(grcoords[:,0:2])
Xfdatapgr=np.array(grcoordp[:,0:3])

# %%
#df=df[df[17]=='Australia']
#df=df[df[8]=='GR']
#df = df[df[14]>0]
#print(df.shape)
#df=df.sort(df[14],ascending=False)
#df=df[df[8]!='GR']


# if zoom_lat>0 and zoom_lat<180:
#     df=df[df[4]<(lat+(zoom_lat/2))]
#     df=df[df[4]>(lat-(zoom_lat/2))]
# if zoom_lat>0 and zoom_lat<360:
#     df=df[df[5]<(lon+(zoom_lon/2))]
#     df=df[df[5]>(lon-(zoom_lon/2))]
# #print('*',df[df[8]=='GR'].shape)


#print(df1.shape)
print(df.shape)
#df[df[8]=='US']

df11=None
df11=df.copy()
#df12=df1.copy()

print(df11.shape)

df11[21]=None
df11[22]=None


df11[21]=abs(df11[4].astype(int)
)
df11[22]=abs(df11[5].astype(int)
)

    
df11=df11.sort_values(by=[22,21],ascending=[1,1])
#coords = df11.as_matrix(columns =[4,5,0]) 

#coordp = df11.as_matrix(columns =[18,19,20]) 

coords = df11[[4,5,0]].to_numpy()
coordp = df11[[18,19,20]].to_numpy()




lats=coords[:,0]
lons=coords[:,1]
gid=coords[:,2]
df11.shape
# df11[df11[0]==5880568]
# Out:
# (4708904, 21)
# (4708904, 21)
# (4708904, 23)

# %%
Xfdata=np.array(coords[:,0:2])
Xfdatap=np.array(coordp[:,0:3])

# %%
Xfdata.shape,Xfdatap.shape
# Out:
# ((4708904, 2), (4708904, 3))

# %%
# %matplotlib qt
myplot(coordp[:,0],coordp[:,1],coordp[:,2])

# %%
def doMDS2(fdata):
    import numpy as np
    t0=time.time()
    #seed = np.random.seed(seed=3)
    #seed=1
    #CALCULATE DIF MATRICES

    a=squareform(pdist(fdata, (lambda u,v: haversine(u,v))))

    mds = MDS(2, metric=True ,max_iter=100, n_init=2, dissimilarity='precomputed', n_jobs=-1)
#     temp=mds.fit(a)
#     stress2=temp.stress_
    tdata = mds.fit_transform(a)

   
    etime=(time.time()-t0)/60
    print("Time min: " ,(time.time()-t0)/60)
    return tdata,etime,a
def doMDS3(fdata):
    import numpy as np
    t0=time.time()
    seed = np.random.seed(seed=3)
    #seed=1
    #CALCULATE DIF MATRICES

    a=squareform(pdist(fdata, (lambda u,v: haversine(u,v))))

    mds = MDS(2, metric=False, max_iter=100, n_init=2, n_jobs=-1)
#     temp=mds.fit(a)
#     stress2=temp.stress_
    tdata = mds.fit_transform(a)

   
    etime=(time.time()-t0)/60
    print("Time min: " ,(time.time()-t0)/60)
    return tdata,etime,a

# %%
# import time
# t0=time.time()
# %matplotlib qt


# rep_points=start_cluster(coords[:,0:3],7,70000,df)

# print('Remain for process :' , len(rep_points))

# mylats,mylons,names,country,X,Y,Z = [],[],[],[],[],[],[]
# mylats=rep_points.values[:,0]
# mylons=rep_points.values[:,1]
# names=rep_points.values[:,2]
# X=rep_points.values[:,6]
# Y=rep_points.values[:,7]
# Z=rep_points.values[:,8]
# country=np.asarray(rep_points.values[:,3]);
# cont=np.asarray(rep_points.values[:,5]);
# mycities2=rep_points.values
# mycities=coords
# plotmap2(mycities2,"DBSCAN CLUSTERED DATA OUR METHOD ")
# toins=np.array([-80,-180,'Extreme Point 1','Antartica',-1,'ANT'])
# toins2=np.array([87,180,'Extreme Point 2','North Pole',-1,'AC'])
# toins.shape
# toins=np.reshape(toins,(-1,1)).T
# toins2=np.reshape(toins,(-1,1)).T
# # mycities3=np.append(mycities2,toins, axis=0)
# # mycities3=np.append(mycities3,toins2, axis=0)






# # np.save(pref+'Acoords1.npy', mycities) 
# # np.save(pref+'Acoords2.npy', mycities2) 



# xyMerc=plotmap2(mycities2,"FILTERED DATA");

# #IMPORT DATA
# fdata2=p2cart(mylats,mylons);
# fdatac=[(X,Y,Z)]
# xyMerc=np.transpose(xyMerc)
# fdata=mycities2[:,0:2]
# gvdata=[(mycities2[:,0]-mycities2[:,0].min())/mycities2[:,0].max(),(mycities2[:,1]-mycities2[:,1].min())/mycities2[:,1].max()]
# xx=normalize(fdata2, axis=1, norm='l2');
# #NORMALISE DATA
# #xyMerc = normalize(xyMerc, axis=1, norm='l2')
# fdata2[:,0]=fdata2[:,0]-fdata2[:,0].min()
# fdata2[:,1]=fdata2[:,1]-fdata2[:,1].min()
# fdata2[:,2]=fdata2[:,2]-fdata2[:,2].min()
# fdata2[:,0]=fdata2[:,0]/fdata2[:,0].max()
# fdata2[:,1]=fdata2[:,1]/fdata2[:,1].max()
# fdata2[:,2]=fdata2[:,2]/fdata2[:,2].max()
# fdataM=np.copy(fdata)
# fdataM1=np.copy(fdata).astype(float)
# fdataM[:,0]=fdataM[:,0]-fdataM[:,0].min()
# fdataM[:,1]=fdataM[:,1]-fdataM[:,1].min()

# cos=np.cos(np.radians(fdataM1[:,0]));
# # fdataM1[:,0]=fdataM1[:,0]+90
# # fdataM1[:,1]=fdataM1[:,1]+180
# fdataM[:,0]=fdataM[:,0]*222.39;
# fdataM[:,1]=fdataM[:,1]*111.20;


# # fdataM1[:,1]=fdataM1[:,1]*cos *111.20
# fdataM1[:,1]=fdataM1[:,1]*111.20;
# fdataM1[:,0]=fdataM1[:,0]*222.39;
# #plotmap(mycities2,"DBSCAN CLUSTERED DATA")
# #xx=xx-xx.min()
# #xx=xx/xx.max()
# print("Time min: " ,(time.time()-t0)/60)
# print(coords.shape,mycities2.shape)

# %%
# #plotmap(mycities2,"DBSCAN CLUSTERED DATA")
# #rep_points
# mycities2=rep_points.values

# %%
# %matplotlib qt
# plotmap2(coords,"ORIGINAL DATA 4.708.904 POI")

# %%
# %matplotlib qt
# plotmap2(mycities2,"DBSCAN CLUSTERED DATA (OUR METHOD) 66.863 POI ")

# %%
import numpy as np
pref='66863-3110.5694130539896-'
Xtdata = np.load(pref+'Xtdata.npy', allow_pickle=True)
trans_dataX = np.load(pref+'trans_dataX.npy', allow_pickle=True)
mycities2 = np.load(pref+'mycities2.npy', allow_pickle=True)
print(Xtdata.shape,trans_dataX.shape,mycities2.shape)
# Out:
# (66863, 2) (66863, 2) (66863, 15)

# %%
import pickle
pref2="23330-79.58774687846501-"
pref3="11344-16.339787352085114-"
filename = pref2+'regressormodel3.sav'
#pickle.dump(regressormodel3, open(filename, 'wb'))
regressormodel3 = pickle.load(open(filename, 'rb'))
filename = pref2+'regressormodel2.sav'
#pickle.dump(regressormodel3, open(filename, 'wb'))
regressormodel2 = pickle.load(open(filename, 'rb'))
filename = pref3+'regressormodel3.sav'
#pickle.dump(regressormodel3, open(filename, 'wb'))
regressormodel31 = pickle.load(open(filename, 'rb'))
filename = pref3+'regressormodel2.sav'
#pickle.dump(regressormodel3, open(filename, 'wb'))
regressormodel21 = pickle.load(open(filename, 'rb'))
print(Xtdata.min(),Xtdata.max())
myplot(Xtdata[:,0],Xtdata[:,1])
print(trans_dataX.min(),trans_dataX.max())
myplot(trans_dataX[:,0],trans_dataX[:,1])
# Out:
# -1.0 0.982631422638385
# -0.7390555517824855 0.7233913581665572

# %%
Xdata=np.array(mycities2[:,0:2])
Xdatap=np.array(mycities2[:,6:9])
Xdata,Xdatap

#myplot(Xdatap[:,0],Xdatap[:,1],Xdatap[:,2])
# myplot(Xdata[:,0],Xdata[:,1])
# Out:
# (array([[0.25174, 0.78177],
#         [6.50815, 3.7793099999999997],
#         [5.61667, 0.11667000000000001],
#         ...,
#         [69.31244000000001, 179.10976000000002],
#         [70.93515, -179.61762],
#         [71.1392, -179.75143]], dtype=object),
#  array([[0.9999995827674866, 0.5083611607551575, 0.4990955889225006],
#         [0.9957656860351562, 0.5343647599220276, 0.5542962551116943],
#         [0.9976630210876465, 0.5025346279144287, 0.5464566946029663],
#         ...,
#         [0.322258859872818, 0.5042791962623596, 0.9722305536270142],
#         [0.3356000781059265, 0.5004217028617859, 0.9771524667739868],
#         [0.33728745579719543, 0.500812828540802, 0.9777440428733826]],
#        dtype=object))

# %%
# Xtdata,etime,D=doMDS2(Xdata)
# #MERGE RESULTS

# Xtdata.shape
# Out:
# Time min:  3110.5694198727606
# (66863, 2)

# %%
# from sklearn import manifold
# start2 = time.time()
# mds = manifold.MDS(2, metric=True,max_iter=100, n_init=2 ,n_jobs=-1)
# trans_dataX = mds.fit_transform(Xdatap)
# print ('Time taken  is {} min\n'.format((time.time()-start2)/60))

# trans_dataX.shape

# %%
# Xtdata[:,0]=Xtdata[:,0]/abs(Xtdata[:,0]).max()
# Xtdata[:,1]=Xtdata[:,1]/abs(Xtdata[:,1]).max()

# Xtdata[:,0].max(),Xtdata[:,0].min()

# %%
# %matplotlib qt
import time
from mds import landmark_MDS
import matplotlib.pyplot as plt
from scipy.spatial import distance
X=Xdatap
color=fill_color(mycities2)
import random
lands = random.sample(range(0,X.shape[0],1),10698)
lands = np.array(lands,dtype=int)
Dl2 = distance.cdist(X[lands,:], X, 'euclidean')
start = time.time()
xla_211 = landmark_MDS(Dl2,lands,2)
print (xla_211.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))

# plt.figure()
# for color, i, target_name in zip(colors, [0, 1, 2], target_names):
#     plt.scatter(xl_2[y == i, 0], xl_2[y == i, 1], alpha=.8, color=color,label=target_name)
# plt.legend(loc='best', shadow=False, scatterpoints=1)
# plt.title('Landmark MDS of IRIS dataset')
# plt.show()
import matplotlib.pyplot as tpl214111
tpl214111.figure()
tpl214111.rcParams["figure.figsize"] = [10.24,10.24]
tpl214111.tight_layout()
tpl214111.axis('off')
tpl214111.scatter(xla_211[:,0], xla_211[:,1], marker='.',c=color)
tpl214111.savefig(pref+'-LMDS60.png', format='png', dpi=100)
tpl214111.show()
# Out:
# (66863, 2) Time taken  is 1.5979251623153687 min

# %%
# Out:
# (0.982631422638385, -1.0)

# %%
# mycities2=np.concatenate([mycities2, Xtdata], axis=1)

# mycities2.shape
# Out:
# (66863, 11)

# %%
# #x_train ,x_test = train_test_split(mycities2[:,0:2].copy(),test_size=0.1) 
# #mycities2=np.concatenate([mycities2, tdata], axis=1)
# mycities2=np.concatenate([mycities2, trans_dataX], axis=1)

# mycities2.shape
# np.save(pref+'Xtdata.npy', Xtdata) 
# #Xtdata = np.load(pref+'Xtdata.npy')
# np.save(pref+'trans_dataX.npy', trans_dataX) 
# #trans_dataX = np.load(pref+'trans_dataX.npy')

# np.save(pref+'mycities2.npy', mycities2) 
# #mycities2 = np.load(pref+'mycities2.npy')
# mycities2[0]

# %%
# Out:
# (66863, 2) (66863, 2) (66863, 15)

# %%
# Out:
# -1.0 0.982631422638385
# -0.7390555517824855 0.7233913581665572

# %%
# %matplotlib qt
color=fill_color(mycities2)
# colorx=df11
# colx=np.array(colorx)
# color=fill_color2(colx,17)
#color="0.1"
import matplotlib.pyplot as plt35
plt35.figure()
plt35.rcParams["figure.figsize"] = [10.24,10.24]
plt35.tight_layout()
plt35.axis('off')
plt35.scatter(Xtdata[:,0], Xtdata[:,1], marker='.',c=color)
plt35.savefig(pref+'-MDSh .png', format='png', dpi=100)
plt35.show()


import matplotlib.pyplot as pl45
pl45.figure()
pl45.rcParams["figure.figsize"] = [10.24,10.24]
pl45.tight_layout()
pl45.axis('off')
pl45.scatter(trans_dataX[:,0], trans_dataX[:,1], marker='.',c=color)
pl45.savefig(pref+'-MDSe .png', format='png', dpi=100)
pl45.show()

# %%
from sklearn.model_selection import train_test_split
x_train ,x_test = train_test_split(mycities2.copy(),test_size=0.8) 
fdata=np.array(x_train[:,0:2])
Nfdata=np.array(x_train[:,13:15])
fdatap=np.array(x_train[:,6:9])
tdata=np.array(x_train[:,9:11])
tdatap=np.array(x_train[:,11:13])


fdatae=np.array(x_test[:,0:2])
Nfdatae=np.array(x_test[:,13:15])
fdataep=np.array(x_test[:,6:9])
tdatae=np.array(x_test[:,9:11])
tdataep=np.array(x_test[:,11:13])

x_test_s ,x_test_b = train_test_split(x_test,test_size=0.8) 

fdatae_s=np.array(x_test_s[:,0:2])
Nfdatae_s=np.array(x_test_s[:,13:15])
fdataep_s=np.array(x_test_s[:,6:9])
tdatae_s=np.array(x_test_s[:,9:11])
tdataep_s=np.array(x_test_s[:,11:13])

fdatae_b=np.array(x_test_b[:,0:2])
Nfdatae_b=np.array(x_test_b[:,13:15])
fdataep_b=np.array(x_test_b[:,6:9])
tdatae_b=np.array(x_test_b[:,9:11])
tdataep_b=np.array(x_test_b[:,11:13])




x_train.shape ,x_test.shape,x_test_s.shape,x_test_b.shape
# Out:
# ((13372, 15), (53491, 15), (10698, 15), (42793, 15))

# %%
Xdata10=np.array(x_test_s[:,0:2])
Xdatap10=np.array(x_test_s[:,6:9])
Xdata10,Xdatap10
# Out:
# (array([[41.59029, 61.021969999999996],
#         [62.61666999999999, 88.71667],
#         [-4.55, -74.03333],
#         ...,
#         [36.34347, 7.63885],
#         [30.5563, -90.01201999999999],
#         [36.67555, 54.29896]], dtype=object),
#  array([[0.6811808943748474, 0.8301473259925842, 0.833669900894165],
#         [0.5047343373298645, 0.732749342918396, 0.9479265213012695],
#         [0.636806845664978, 0.02083863876760006, 0.45667797327041626],
#         ...,
#         [0.899588942527771, 0.5552816987037659, 0.7974667549133301],
#         [0.4994747042655945, 0.06925515085458755, 0.7546575665473938],
#         [0.7340875864028931, 0.8285641074180603, 0.7998352646827698]],
#        dtype=object))

# %%
# %matplotlib qt

import time
from mds import landmark_MDS
import matplotlib.pyplot as plt
from scipy.spatial import distance
X=Xdatap10
color=fill_color(x_test_s)
import random
lands = random.sample(range(0,X.shape[0],1),10698)
lands = np.array(lands,dtype=int)
Dl2 = distance.cdist(X[lands,:], X, 'euclidean')
start = time.time()
xla_211 = landmark_MDS(Dl2,lands,2)
print (xla_211.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))

# plt.figure()
# for color, i, target_name in zip(colors, [0, 1, 2], target_names):
#     plt.scatter(xl_2[y == i, 0], xl_2[y == i, 1], alpha=.8, color=color,label=target_name)
# plt.legend(loc='best', shadow=False, scatterpoints=1)
# plt.title('Landmark MDS of IRIS dataset')
# plt.show()
import matplotlib.pyplot as tpl214111
tpl214111.figure()
tpl214111.rcParams["figure.figsize"] = [10.24,10.24]
tpl214111.tight_layout()
tpl214111.axis('off')
tpl214111.scatter(xla_211[:,0], xla_211[:,1], marker='.',c=color)
tpl214111.savefig(pref+'-LMDS10.png', format='png', dpi=100)
tpl214111.show()
# Out:
# (10698, 2) Time taken  is 1.4635060151418051 min

# %%
Xdata40=np.array(x_test_b[:,0:2])
Xdatap40=np.array(x_test_b[:,6:9])
Xdata40,Xdatap40
# Out:
# (array([[25.21309, 88.19363],
#         [-10.6, 20.866670000000003],
#         [-21.23333, -67.83333],
#         ...,
#         [37.7, 53.86666999999999],
#         [11.92111, 119.935],
#         [58.744080000000004, 17.86567]], dtype=object),
#  array([[0.5138471126556396, 0.9553244113922119, 0.7128196954727173],
#         [0.9592965841293335, 0.6771345138549805, 0.40366309881210327],
#         [0.6756575107574463, 0.0683903768658638, 0.3133030831813812],
#         ...,
#         [0.7333635687828064, 0.8224173188209534, 0.8070783019065857],
#         [0.25516557693481445, 0.9268338084220886, 0.6015371680259705],
#         [0.7473324537277222, 0.5815488696098328, 0.9310328364372253]],
#        dtype=object))

# %%
# %matplotlib qt

import time
from mds import landmark_MDS
import matplotlib.pyplot as plt
from scipy.spatial import distance
X=Xdatap40
color=fill_color(x_test_b)
import random
lands = random.sample(range(0,X.shape[0],1),10698)
lands = np.array(lands,dtype=int)
Dl2 = distance.cdist(X[lands,:], X, 'euclidean')
start = time.time()
xla_211 = landmark_MDS(Dl2,lands,2)
print (xla_211.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))

# plt.figure()
# for color, i, target_name in zip(colors, [0, 1, 2], target_names):
#     plt.scatter(xl_2[y == i, 0], xl_2[y == i, 1], alpha=.8, color=color,label=target_name)
# plt.legend(loc='best', shadow=False, scatterpoints=1)
# plt.title('Landmark MDS of IRIS dataset')
# plt.show()
import matplotlib.pyplot as tpl214111
tpl214111.figure()
tpl214111.rcParams["figure.figsize"] = [10.24,10.24]
tpl214111.tight_layout()
tpl214111.axis('off')
tpl214111.scatter(xla_211[:,0], xla_211[:,1], marker='.',c=color)
tpl214111.savefig(pref+'-LMDS40.png', format='png', dpi=100)
tpl214111.show()
# Out:
# (42793, 2) Time taken  is 1.4362836877504985 min

# %%
# import numpy as np
# import time
# import matplotlib.pyplot as pl
# from sklearn import neural_network 
# from sklearn import datasets
# from sklearn.neural_network import MLPRegressor
# from sklearn.metrics import mean_squared_error, explained_variance_score
# from sklearn.model_selection import cross_val_predict
# import sklearn.model_selection as  cross_validation
# # ###########################################
# # Load data

# # Creating Regression Design Matrix 
# x=Nfdatae_s
# y=tdatae_s
# #y=trans_data
# #x_train, x_test, y_train, y_test= cross_validation.train_test_split(x, y, test_size=0.2, random_state=42)
# # ######################################################################
# # Fit regression model
# n_fig=0
# #n_size=500
# #n_size=(45,2,11,)
# n_size= (300, 300)
# start = time.time()
# start2 = time.time()
# for name, nn_unit in [
#         ('MLP using ReLU', neural_network.MLPRegressor(hidden_layer_sizes=n_size,activation='relu', solver='lbfgs'))
#         ]:
#     regressormodel2s=nn_unit.fit(x,y)
#     # Y predicted values
#     yp2s =nn_unit.predict(x)
#     rmse =np.sqrt(mean_squared_error(y,yp2s))
#     #Calculation 10-Fold CV
#     #yp_cv2 = cross_val_predict(regressormodel2s, x, y, cv=10)
#     #rmsecv=np.sqrt(mean_squared_error(y,yp_cv2))
#     print('Method: %s' %name)
#     print('RMSE on the data: %.4f' %rmse)
#    # print('RMSE on 10-fold CV: %.4f' %rmsecv)
#     print ('Time taken  is {} min\n'.format((time.time()-start)/60))
#     start = time.time()
# #     n_fig=n_fig+1
# #     pl.figure(n_fig)
# #     pl.plot(yp, y,'ro')
# #     pl.plot(yp_cv, y,'bo', alpha=0.25, label='10-folds CV')
# #     pl.xlabel('predicted')
# #     pl.title('Method: %s' %name)
# #     pl.ylabel('real')
# #     pl.grid(True)
# #     pl.show()
# print ('Time taken  is {} min\n'.format((time.time()-start2)/60))
# Out:
# Method: MLP using ReLU
# RMSE on the data: 0.0379
# Time taken  is 0.9803483406702678 min
#
# Time taken  is 0.9803735454877217 min

# %%
import numpy as np
import time
import matplotlib.pyplot as pl
from sklearn import neural_network 
from sklearn import datasets
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, explained_variance_score
from sklearn.model_selection import cross_val_predict
import sklearn.model_selection as  cross_validation
# ###########################################
# Load data

# Creating Regression Design Matrix 
x=fdataep_s
y=tdataep_s
#y=trans_data
#x_train, x_test, y_train, y_test= cross_validation.train_test_split(x, y, test_size=0.2, random_state=42)
# ######################################################################
# Fit regression model
n_fig=0
#n_size=500
#n_size=(45,2,11,)
n_size= (300, 300)
start = time.time()
start2 = time.time()
for name, nn_unit in [
        ('MLP using ReLU', neural_network.MLPRegressor(hidden_layer_sizes=n_size,activation='relu', solver='lbfgs'))
        ]:
    regressormodel3s=nn_unit.fit(x,y)
    # Y predicted values
    yp3s =nn_unit.predict(x)
    rmse =np.sqrt(mean_squared_error(y,yp3s))
    #Calculation 10-Fold CV
    #yp_cv3 = cross_val_predict(regressormodel3s, x, y, cv=10)
    #rmsecv=np.sqrt(mean_squared_error(y,yp_cv3))
    print('Method: %s' %name)
    print('RMSE on the data: %.4f' %rmse)
    #print('RMSE on 10-fold CV: %.4f' %rmsecv)
    print ('Time taken  is {} min\n'.format((time.time()-start)/60))
    start = time.time()
#     n_fig=n_fig+1
#     pl.figure(n_fig)
#     pl.plot(yp, y,'ro')
#     pl.plot(yp_cv, y,'bo', alpha=0.25, label='10-folds CV')
#     pl.xlabel('predicted')
#     pl.title('Method: %s' %name)
#     pl.ylabel('real')
#     pl.grid(True)
#     pl.show()
print ('Time taken  is {} min\n'.format((time.time()-start2)/60))
# Out:
# Method: MLP using ReLU
# RMSE on the data: 0.0404
# Time taken  is 0.4060595711072286 min
#
# Time taken  is 0.4060689369837443 min

# %%
# import numpy as np
# import time
# import matplotlib.pyplot as pl
# from sklearn import neural_network 
# from sklearn import datasets
# from sklearn.neural_network import MLPRegressor
# from sklearn.metrics import mean_squared_error, explained_variance_score
# from sklearn.model_selection import cross_val_predict
# import sklearn.model_selection as  cross_validation
# # ###########################################
# # Load data

# # Creating Regression Design Matrix 
# x=Nfdatae_b
# y=tdatae_b
# #y=trans_data
# #x_train, x_test, y_train, y_test= cross_validation.train_test_split(x, y, test_size=0.2, random_state=42)
# # ######################################################################
# # Fit regression model
# n_fig=0
# #n_size=500
# #n_size=(45,2,11,)
# n_size= (300, 300)
# start = time.time()
# start2 = time.time()
# for name, nn_unit in [
#         ('MLP using ReLU', neural_network.MLPRegressor(hidden_layer_sizes=n_size,activation='relu', solver='lbfgs'))
#         ]:
#     regressormodel2b=nn_unit.fit(x,y)
#     # Y predicted values
#     yp2b =nn_unit.predict(x)
#     rmse =np.sqrt(mean_squared_error(y,yp2b))
#     #Calculation 10-Fold CV
#     #yp_cv2 = cross_val_predict(regressormodel2b, x, y, cv=10)
#     #rmsecv=np.sqrt(mean_squared_error(y,yp_cv2))
#     print('Method: %s' %name)
#     print('RMSE on the data: %.4f' %rmse)
#     #print('RMSE on 10-fold CV: %.4f' %rmsecv)
#     print ('Time taken  is {} min\n'.format((time.time()-start)/60))
#     start = time.time()
# #     n_fig=n_fig+1
# #     pl.figure(n_fig)
# #     pl.plot(yp, y,'ro')
# #     pl.plot(yp_cv, y,'bo', alpha=0.25, label='10-folds CV')
# #     pl.xlabel('predicted')
# #     pl.title('Method: %s' %name)
# #     pl.ylabel('real')
# #     pl.grid(True)
# #     pl.show()
# print ('Time taken  is {} min\n'.format((time.time()-start2)/60))
# Out:
# Method: MLP using ReLU
# RMSE on the data: 0.0347
# Time taken  is 2.567329780260722 min
#
# Time taken  is 2.5673458059628804 min

# %%
import numpy as np
import time
import matplotlib.pyplot as pl
from sklearn import neural_network 
from sklearn import datasets
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, explained_variance_score
from sklearn.model_selection import cross_val_predict
import sklearn.model_selection as  cross_validation
# ###########################################
# Load data

# Creating Regression Design Matrix 
x=fdataep_b
y=tdataep_b
#y=trans_data
#x_train, x_test, y_train, y_test= cross_validation.train_test_split(x, y, test_size=0.2, random_state=42)
# ######################################################################
# Fit regression model
n_fig=0
#n_size=500
#n_size=(45,2,11,)
n_size= (300, 300)
start = time.time()
start2 = time.time()
for name, nn_unit in [
        ('MLP using ReLU', neural_network.MLPRegressor(hidden_layer_sizes=n_size,activation='relu', solver='lbfgs'))
        ]:
    regressormodel3b=nn_unit.fit(x,y)
    # Y predicted values
    yp3b =nn_unit.predict(x)
    rmse =np.sqrt(mean_squared_error(y,yp3b))
    #Calculation 10-Fold CV
    #yp_cv3 = cross_val_predict(regressormodel3b, x, y, cv=10)
    #rmsecv=np.sqrt(mean_squared_error(y,yp_cv3))
    print('Method: %s' %name)
    print('RMSE on the data: %.4f' %rmse)
    #print('RMSE on 10-fold CV: %.4f' %rmsecv)
    print ('Time taken  is {} min\n'.format((time.time()-start)/60))
    start = time.time()
#     n_fig=n_fig+1
#     pl.figure(n_fig)
#     pl.plot(yp, y,'ro')
#     pl.plot(yp_cv, y,'bo', alpha=0.25, label='10-folds CV')
#     pl.xlabel('predicted')
#     pl.title('Method: %s' %name)
#     pl.ylabel('real')
#     pl.grid(True)
#     pl.show()
print ('Time taken  is {} min\n'.format((time.time()-start2)/60))
# Out:
# Method: MLP using ReLU
# RMSE on the data: 0.0351
# Time taken  is 1.3590518434842427 min
#
# Time taken  is 1.359065878391266 min

# %%
from sklearn.metrics import mean_squared_error
start = time.time()
Dsh=euclidean_distances(tdatae_s.astype(np.float64))
Dshm=euclidean_distances(yp2s.astype(np.float64))

Dse=euclidean_distances(tdataep_s.astype(np.float64))
Dsem=euclidean_distances(yp3s.astype(np.float64))



Dbh=euclidean_distances(tdatae_b.astype(np.float64))
Dbhm=euclidean_distances(yp2b.astype(np.float64))

Dbe=euclidean_distances(tdataep_b.astype(np.float64))
Dbem=euclidean_distances(yp3b.astype(np.float64))

print(mean_squared_error(Dsh, Dshm),mean_squared_error(Dse, Dsem))
print(mean_squared_error(Dbh, Dbhm),mean_squared_error(Dbe, Dbem))

print ('Time taken  is {} min\n'.format((time.time()-start)/60))
start = time.time()
Dsh=Dsh/Dsh.max()
Dshm=Dshm/Dshm.max()
Dse=Dse/Dse.max()
Dsem=Dsem/Dsem.max()
Dbh=Dbh/Dbh.max()
Dbhm=Dbhm/Dbhm.max()
Dbe=Dbe/Dbe.max()
Dbem=Dbem/Dbem.max()
print(mean_squared_error(Dsh, Dshm),mean_squared_error(Dse, Dsem))
print(mean_squared_error(Dbh, Dbhm),mean_squared_error(Dbe, Dbem))

print ('Time taken  is {} min\n'.format((time.time()-start)/60))
# Dsh=squareform(pdist(fdata, (lambda u,v: haversine(u,v))))
# Dbh=squareform(pdist(fdata, (lambda u,v: haversine(u,v))))
# # D=euclidean_distances(fdataM.astype(np.float64))
# #E=euclidean_distances(fdatac.astype(np.float64))
# print(mean_squared_error(A, B),mean_squared_error(A, C))
# print(mean_squared_error(B, C),mean_squared_error(B, D))
# print(mean_squared_error(D, C),mean_squared_error(A, D))
# print(mean_squared_error(D, D),mean_squared_error(C, C))
# A=A/A.max()
# B=B/B.max()
# C=C/C.max()
# # E=E/E.max()
# D=D/D.max()
# print("----After norm---------------")
# print(mean_squared_error(A, B),mean_squared_error(A, C))
# print(mean_squared_error(B, C),mean_squared_error(B, D))
# print(mean_squared_error(D, C),mean_squared_error(A, D))
# print(mean_squared_error(D, D),mean_squared_error(C, C))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-3be9b738902a> in <module>
#       2 start = time.time()
#       3 Dsh=euclidean_distances(tdatae_s.astype(np.float64))
# ----> 4 Dshm=euclidean_distances(yp2s.astype(np.float64))
#       5
#       6 Dse=euclidean_distances(tdataep_s.astype(np.float64))
#
# NameError: name 'yp2s' is not defined

# %%
start = time.time()
x=Nfdata
ryp2s =regressormodel2s.predict(x)
print (ryp2s.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))

start = time.time()
x=fdatap
ryp3s =regressormodel3s.predict(x)
print (ryp3s.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))
start = time.time()
x=Nfdata
ryp2b =regressormodel2b.predict(x)
print (ryp2b.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))
start = time.time()
x=fdatap
ryp3b =regressormodel3b.predict(x)
print (ryp3b.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))
# Out:
# (13372, 2) Time taken  is 0.0020712574323018393 min
#
# (13372, 2) Time taken  is 0.0013851126035054524 min
#
# (13372, 2) Time taken  is 0.0013411760330200196 min
#
# (13372, 2) Time taken  is 0.0019584854443868 min

# %%
tdatap.shape
# Out:
# (13372, 2)

# %%
Dsh.shape,Dshm.shape,Dse.shape,Dsem.shape
# Out:
# ((10698, 10698), (10698, 10698), (10698, 10698), (10698, 10698))

# %%
start = time.time()
rmseSh =np.sqrt(mean_squared_error(tdata,ryp2s))
rmseSe =np.sqrt(mean_squared_error(tdatap,ryp3s))
rmseBh =np.sqrt(mean_squared_error(tdata,ryp2b))
rmseBe =np.sqrt(mean_squared_error(tdatap,ryp3b))

print(rmseSh,rmseSe,rmseBh,rmseBe)    
print ('Time taken  is {} min\n'.format((time.time()-start)/60))
# Out:
# 0.035272802547092134 0.03587471397429689 0.03368450119899349 0.03604430240000797
# Time taken  is 0.0001772324244181315 min

# %%
from sklearn.metrics import mean_squared_error
start = time.time()
Dh=squareform(pdist(fdata, (lambda u,v: haversine(u,v))))
Ds=euclidean_distances(fdatap.astype(np.float64))

Dsh=euclidean_distances(tdata.astype(np.float64))
Dshm=euclidean_distances(ryp2s.astype(np.float64))

Dse=euclidean_distances(tdatap.astype(np.float64))
Dsem=euclidean_distances(ryp3s.astype(np.float64))

#Dbh=euclidean_distances(tdata.astype(np.float64))
Dbhm=euclidean_distances(ryp2b.astype(np.float64))

#Dbe=euclidean_distances(tdatap.astype(np.float64))
Dbem=euclidean_distances(ryp3b.astype(np.float64))



print(mean_squared_error(Dsh, Dshm),mean_squared_error(Dse, Dsem))
print(mean_squared_error(Dsh, Dbhm),mean_squared_error(Dse, Dbem))
print ('Time taken  is {} min\n'.format((time.time()-start)/60))   





# Dbh=euclidean_distances(tdatae_b.astype(np.float64))
# Dbhm=euclidean_distances(yp2b.astype(np.float64))

# Dbe=euclidean_distances(tdataep_b.astype(np.float64))
# Dbem=euclidean_distances(yp3b.astype(np.float64))

# print(mean_squared_error(Dsh, Dshm),mean_squared_error(Dse, Dsem))
# print(mean_squared_error(Dbh, Dbhm),mean_squared_error(Dbe, Dbem))
# Out:
# 0.0013473937227500184 0.0015362275900341759
# 0.0010826384563288368 0.001393464175253232
# Time taken  is 14.618552867571513 min

# %%
start = time.time()
Dsh=Dsh/Dsh.max()
Dshm=Dshm/Dshm.max()
Dse=Dse/Dse.max()
Dsem=Dsem/Dsem.max()

Dbhm=Dbhm/Dbhm.max()

Dbem=Dbem/Dbem.max()
print(mean_squared_error(Dsh, Dshm),mean_squared_error(Dse, Dsem))
print(mean_squared_error(Dsh, Dbhm),mean_squared_error(Dse, Dbem))
print ('Time taken  is {} min\n'.format((time.time()-start)/60))
# Out:
# 0.0003463752362407064 0.0012931259271196484
# 0.0005652432906546181 0.0011936884940786502
# Time taken  is 0.2100136081377665 min

# %%
# %matplotlib qt
import matplotlib.pyplot as plt33
color=fill_color(x_train)
plt33.figure()
plt33.rcParams["figure.figsize"] = [10.24,10.24]
plt33.tight_layout()
plt33.axis('off')
plt33.scatter(tdata[:,0], tdata[:,1], marker='.', c=color)
#plt3.scatter(trans_dataX[:,0], trans_dataX[:,1], marker='.',, c=color,c="0.1")
plt33.savefig(pref+'-Shmds.png', format='png', dpi=100)
plt33.show()


import matplotlib.pyplot as pl43
pl43.figure()
pl43.rcParams["figure.figsize"] = [10.24,10.24]
pl43.tight_layout()
pl43.axis('off')
pl43.scatter(ryp2s[:,0], ryp2s[:,1], marker='.',c=color)
pl43.savefig(pref+'-Shmlp.png', format='png', dpi=100)
pl43.show()

# %%
# %matplotlib qt
import matplotlib.pyplot as plt32
color=fill_color(x_train)
plt32.figure()
plt32.rcParams["figure.figsize"] = [10.24,10.24]
plt32.tight_layout()
plt32.axis('off')
plt32.scatter(tdatap[:,0], tdatap[:,1], marker='.', c=color)
#plt3.scatter(trans_dataX[:,0], trans_dataX[:,1], marker='.',, c=color,c="0.1")
plt32.savefig(pref+'-Semds.png', format='png', dpi=100)
plt32.show()


import matplotlib.pyplot as pl42
pl42.figure()
pl42.rcParams["figure.figsize"] = [10.24,10.24]
pl42.tight_layout()
pl42.axis('off')
pl42.scatter(ryp3s[:,0], ryp3s[:,1], marker='.',c=color)
pl42.savefig(pref+'-Semlp.png', format='png', dpi=100)
pl42.show()

# %%
# %matplotlib qt
import matplotlib.pyplot as plt31
color=fill_color(x_train)
plt31.figure()
plt31.rcParams["figure.figsize"] = [10.24,10.24]
plt31.tight_layout()
plt31.axis('off')
plt31.scatter(tdata[:,0], tdata[:,1], marker='.', c=color)
#plt3.scatter(trans_dataX[:,0], trans_dataX[:,1], marker='.',, c=color,c="0.1")
plt31.savefig(pref+'-Bhmds.png', format='png', dpi=100)
plt31.show()


import matplotlib.pyplot as pl41
pl41.figure()
pl41.rcParams["figure.figsize"] = [10.24,10.24]
pl41.tight_layout()
pl41.axis('off')
pl41.scatter(ryp2b[:,0], ryp2b[:,1], marker='.',c=color)
pl41.savefig(pref+'-Bhmlp.png', format='png', dpi=100)
pl41.show()

# %%
#%matplotlib qt
import matplotlib.pyplot as plt3
color=fill_color(x_train)
plt3.figure()
plt3.rcParams["figure.figsize"] = [10.24,10.24]
plt3.tight_layout()
plt3.axis('off')
plt3.scatter(tdatap[:,0], tdatap[:,1], marker='.', c=color)
#plt3.scatter(trans_dataX[:,0], trans_dataX[:,1], marker='.',, c=color,c="0.1")
plt3.savefig(pref+'-Bemds.png', format='png', dpi=100)
plt3.show()


import matplotlib.pyplot as pl4
pl4.figure()
pl4.rcParams["figure.figsize"] = [10.24,10.24]
pl4.tight_layout()
pl4.axis('off')
pl4.scatter(ryp3b[:,0], ryp3b[:,1], marker='.',c=color)
pl4.savefig(pref+'-Bemlp.png', format='png', dpi=100)
pl4.show()

# %%
# %matplotlib qt
import os
import matplotlib.pyplot as plt8221
import scipy as sp
import scipy.misc
import numpy
import cv2
import imreg_dft as ird

plt8221.rcParams["figure.figsize"] = [20.48,20.48]
# im0 = plt2.imread('bmds.png')
# # the image to be transformed
# im1 = plt2.imread('bmlp.png')
im0 = numpy.array( cv2.imread(pref+'-Shmds.png',cv2.IMREAD_GRAYSCALE))
im1 = numpy.array(cv2.imread(pref+'-Shmlp.png',cv2.IMREAD_GRAYSCALE))
print(im0.shape,im1.shape)
#im1 = cv2.flip(im1, 1)
result = ird.similarity(im0, im1, numiter=0,exponent='inf',order=3,filter_pcorr=0)

assert "timg" in result
# Maybe we don't want to show plots all the time
im3=result['timg']
tvec = result["tvec"].round(6)
ird.imshow(im0, im1, result['timg'])
plt8221.show()
#plt822.ylabel('mds','mlp','diff')
plt8221.savefig(pref+'-Shicp.png', format='png', dpi=100)
print("scale is {} angle is {} Translation is {}, success rate {:.6g}"
    .format(result['scale'], result['angle'],tuple(result["tvec"]), result["success"]))
# Out:
# (1024, 1024) (1024, 1024)
# scale is 1.0 angle is 0.0 Translation is (-34.11803859822339, -14.172886252344483), success rate 0.0307608

# %%
# %matplotlib qt
import os
import matplotlib.pyplot as plt1822
import scipy as sp
import scipy.misc
import numpy
import cv2
import imreg_dft as ird

plt1822.rcParams["figure.figsize"] = [20.48,20.48]
# im0 = plt2.imread('bmds.png')
# # the image to be transformed
# im1 = plt2.imread('bmlp.png')
im0 = numpy.array( cv2.imread(pref+'-Semds.png',cv2.IMREAD_GRAYSCALE))
im1 = numpy.array(cv2.imread(pref+'-Semlp.png',cv2.IMREAD_GRAYSCALE))
print(im0.shape,im1.shape)
#im1 = cv2.flip(im1, 1)
result = ird.similarity(im0, im1, numiter=0,exponent='inf',order=3,filter_pcorr=0)

assert "timg" in result
# Maybe we don't want to show plots all the time
im3=result['timg']
tvec = result["tvec"].round(6)
ird.imshow(im0, im1, result['timg'])
plt1822.show()
#plt822.ylabel('mds','mlp','diff')
plt1822.savefig(pref+'-Seicp.png', format='png', dpi=100)
print("scale is {} angle is {} Translation is {}, success rate {:.6g}"
    .format(result['scale'], result['angle'],tuple(result["tvec"]), result["success"]))
# Out:
# (1024, 1024) (1024, 1024)
# scale is 1.0 angle is 0.0 Translation is (41.0198846400059, 28.610264460017333), success rate 0.0199915

# %%
# %matplotlib qt
import os
import matplotlib.pyplot as plt2822
import scipy as sp
import scipy.misc
import numpy
import cv2
import imreg_dft as ird

plt2822.rcParams["figure.figsize"] = [20.48,20.48]
# im0 = plt2.imread('bmds.png')
# # the image to be transformed
# im1 = plt2.imread('bmlp.png')
im0 = numpy.array( cv2.imread(pref+'-Bhmds.png',cv2.IMREAD_GRAYSCALE))
im1 = numpy.array(cv2.imread(pref+'-Bhmlp.png',cv2.IMREAD_GRAYSCALE))
print(im0.shape,im1.shape)
#im1 = cv2.flip(im1, 1)
result = ird.similarity(im0, im1, numiter=0,exponent='inf',order=3,filter_pcorr=0)

assert "timg" in result
# Maybe we don't want to show plots all the time
im3=result['timg']
tvec = result["tvec"].round(6)
ird.imshow(im0, im1, result['timg'])
plt2822.show()
#plt822.ylabel('mds','mlp','diff')
plt2822.savefig(pref+'-Bhicp.png', format='png', dpi=100)
print("scale is {} angle is {} Translation is {}, success rate {:.6g}"
    .format(result['scale'], result['angle'],tuple(result["tvec"]), result["success"]))
# Out:
# (1024, 1024) (1024, 1024)
# scale is 1.0 angle is 0.0 Translation is (-24.98774866803808, 8.190463317066587), success rate 0.0268267

# %%
# %matplotlib qt
import os
import matplotlib.pyplot as plt8225
import scipy as sp
import scipy.misc
import numpy
import cv2
import imreg_dft as ird

plt8225.rcParams["figure.figsize"] = [20.48,20.48]
# im0 = plt2.imread('bmds.png')
# # the image to be transformed
# im1 = plt2.imread('bmlp.png')
im0 = numpy.array( cv2.imread(pref+'-Bemds.png',cv2.IMREAD_GRAYSCALE))
im1 = numpy.array(cv2.imread(pref+'-Bemlp.png',cv2.IMREAD_GRAYSCALE))
print(im0.shape,im1.shape)
#im1 = cv2.flip(im1, 1)
result = ird.similarity(im0, im1, numiter=2,exponent='inf',order=3,filter_pcorr=2)

assert "timg" in result
# Maybe we don't want to show plots all the time
im3=result['timg']
tvec = result["tvec"].round(6)
ird.imshow(im0, im1, result['timg'])
plt8225.show()
#plt822.ylabel('mds','mlp','diff')
plt8225.savefig(pref+'-Beicp.png', format='png', dpi=100)
print("scale is {} angle is {} Translation is {}, success rate {:.6g}"
    .format(result['scale'], result['angle'],tuple(result["tvec"]), result["success"]))
# Out:
# (1024, 1024) (1024, 1024)
# scale is 0.9609857167572268 angle is -8.452234106847897 Translation is (7.7654577138174545, -23.115845266388135), success rate 0.013674

# %%
Xfdata=np.array(coords[:,0:2])
Xfdatap=np.array(coordp[:,0:3])

# %%
Xfdata[:,0]=Xfdata[:,0]/90
Xfdata[:,1]=Xfdata[:,1]/180

# %%
Xfdata[:,1].min(),Xfdata[:,1].max() ,Xfdata[:,0].min(),Xfdata[:,0].max()
# Out:
# (-0.999997, 1.0, -0.8649555555555556, 0.9090980000000001)

# %%
Xfdata.shape,Xfdatap.shape
# Out:
# ((4708904, 2), (4708904, 3))

# %%
import time
start = time.time()
x=Xfdata
Aryp2s =regressormodel2s.predict(x)
print (Aryp2s.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))

start = time.time()
x=Xfdatap
Aryp3s =regressormodel3s.predict(x)
print (Aryp3s.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))
start = time.time()
x=Xfdata
Aryp2b =regressormodel2b.predict(x)
print (Aryp2b.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))
start = time.time()
x=Xfdatap
Aryp3b =regressormodel3b.predict(x)
print (Aryp3b.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))
# Out:
# (4708904, 2) Time taken  is 0.23473267952601115 min
#
# (4708904, 2) Time taken  is 0.2395738482475281 min
#
# (4708904, 2) Time taken  is 0.23868412574132283 min
#
# (4708904, 2) Time taken  is 0.2443349560101827 min

# %%
# %matplotlib qt
colorx=df11
colx=np.array(colorx)
color=fill_color2(colx,17)
#color="0.1"
# import matplotlib.pyplot as plt3
# plt3.figure()
# plt3.rcParams["figure.figsize"] = [10.24,10.24]
# plt3.tight_layout()
# plt3.axis('off')
# plt3.scatter(Xtdata[:,0], Xtdata[:,1], marker='.',c=color)
# plt3.savefig(pref+'-23fmds.png', format='png', dpi=100)
# plt3.show()


import matplotlib.pyplot as pl14
pl14.figure()
pl14.rcParams["figure.figsize"] = [10.24,10.24]
pl14.tight_layout()
pl14.axis('off')
pl14.scatter(Aryp2s[:,0], Aryp2s[:,1], marker='.',c=color)
pl14.savefig(pref+'-XhSmlp.png', format='png', dpi=100)
pl14.show()
import matplotlib.pyplot as pl144
pl144.figure()
pl144.rcParams["figure.figsize"] = [10.24,10.24]
pl144.tight_layout()
pl144.axis('off')
pl144.scatter(Aryp3s[:,0], Aryp3s[:,1], marker='.',c=color)
pl144.savefig(pref+'-XeSmlp.png', format='png', dpi=100)
pl144.show()
import matplotlib.pyplot as pl114
pl114.figure()
pl114.rcParams["figure.figsize"] = [10.24,10.24]
pl114.tight_layout()
pl114.axis('off')
pl114.scatter(Aryp2b[:,0], Aryp2b[:,1], marker='.',c=color)
pl114.savefig(pref+'-XhBmlp.png', format='png', dpi=100)
pl114.show()

# %%
import matplotlib.pyplot as pl1144
pl1144.figure()
pl1144.rcParams["figure.figsize"] = [10.24,10.24]
pl1144.tight_layout()
pl1144.axis('off')
pl1144.scatter(Aryp3b[:,0], Aryp3b[:,1], marker='.',c=color)
pl1144.savefig(pref+'-XeBmlp.png', format='png', dpi=100)
pl1144.show()

# %%
start = time.time()
from mds import landmark_MDS
import matplotlib.pyplot as plt
from scipy.spatial import distance
X=Xfdatap
colorx=df11
colx=np.array(colorx)
color=fill_color2(colx,17)
import random
lands = random.sample(range(0,X.shape[0],1),8500)
lands = np.array(lands,dtype=int)
Dl2 = distance.cdist(X[lands,:], X, 'euclidean')
start = time.time()
xl_211 = landmark_MDS(Dl2,lands,2)
print (xl_211.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))

# plt.figure()
# for color, i, target_name in zip(colors, [0, 1, 2], target_names):
#     plt.scatter(xl_2[y == i, 0], xl_2[y == i, 1], alpha=.8, color=color,label=target_name)
# plt.legend(loc='best', shadow=False, scatterpoints=1)
# plt.title('Landmark MDS of IRIS dataset')
# plt.show()
print (xl_211.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))
import matplotlib.pyplot as pl214111
pl214111.figure()
pl214111.rcParams["figure.figsize"] = [10.24,10.24]
pl214111.tight_layout()
pl214111.axis('off')
pl214111.scatter(xl_211[:,0], xl_211[:,1], marker='.',c=color)
pl214111.savefig(pref+'-LMDS4m10698L.png', format='png', dpi=100)
pl214111.show()
# Out:
# (4708904, 2) Time taken  is 595.9817850748698 min
#
# (4708904, 2) Time taken  is 595.9821974992752 min

# %%
Xfdatap.shape

# %%
Xfdatagr[:,0]=Xfdatagr[:,0]/90
Xfdatagr[:,1]=Xfdatagr[:,1]/180

# %%
# start = time.time()
# x=Xfdatagr
# grAryp2s =regressormodel2s.predict(x)
# print (grAryp2s.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))

start = time.time()
x=Xfdatapgr
grAryp3s =regressormodel3s.predict(x)
print (grAryp3s.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))
# start = time.time()
# x=Xfdatagr
# grAryp2b =regressormodel2b.predict(x)
# print (grAryp2b.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))
start = time.time()
x=Xfdatapgr
grAryp3b =regressormodel3b.predict(x)
print (grAryp3b.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))
# Out:
# (14969, 2) Time taken  is 0.0010834137598673503 min
#
# (14969, 2) Time taken  is 0.0010886430740356446 min

# %%
Xfdatapgr
# Out:
# array([[0.8718109 , 0.6707935 , 0.7901649 ],
#        [0.8728548 , 0.6677649 , 0.7905755 ],
#        [0.86839956, 0.67854345, 0.7899107 ],
#        ...,
#        [0.8432275 , 0.6670632 , 0.8261346 ],
#        [0.8438369 , 0.66620576, 0.8259195 ],
#        [0.8434679 , 0.66606355, 0.8263902 ]], dtype=float32)

# %%
from sklearn import manifold
start2 = time.time()
mds = manifold.MDS(2, metric=True,max_iter=100, n_init=2 ,n_jobs=-1)
trans_dataXgr = mds.fit_transform(Xfdatapgr)
print ('Time taken  is {} min\n'.format((time.time()-start2)/60))

trans_dataXgr.shape
# Out:
# Time taken  is 14.250297359625499 min
# (14969, 2)

# %%
# Xdatapt=np.array(x_test_b[:,6:9])
# from sklearn import manifold
# start2 = time.time()
# mds = manifold.MDS(2, metric=True,max_iter=100, n_init=2 ,n_jobs=-1)
# trans_dataXT = mds.fit_transform(Xdatapt)
# print ('Time taken  is {} min\n'.format((time.time()-start2)/60))

# Xdatapt.shape
# Out:
# Time taken  is 141.94705041646958 min
# (42793, 3)

# %%
# %matplotlib qt
from mds import landmark_MDS
import matplotlib.pyplot as plt
import time
from scipy.spatial import distance
X=Xfdatapgr
colorx=df12
colx=np.array(colorx)
color=fill_color2(colx,17)
import random
lands = random.sample(range(0,X.shape[0],1),10698)
lands = np.array(lands,dtype=int)
Dl2 = distance.cdist(X[lands,:], X, 'euclidean')
start = time.time()
xl_2 = landmark_MDS(Dl2,lands,2)
print (xl_2.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))

# plt.figure()
# for color, i, target_name in zip(colors, [0, 1, 2], target_names):
#     plt.scatter(xl_2[y == i, 0], xl_2[y == i, 1], alpha=.8, color=color,label=target_name)
# plt.legend(loc='best', shadow=False, scatterpoints=1)
# plt.title('Landmark MDS of IRIS dataset')
# plt.show()
import matplotlib.pyplot as pl21411
pl21411.figure()
pl21411.rcParams["figure.figsize"] = [10.24,10.24]
pl21411.tight_layout()
pl21411.axis('off')
pl21411.scatter(xl_2[:,0], xl_2[:,1], marker='.',c=color)
pl21411.savefig(pref+'-LMDSgr10698.png', format='png', dpi=100)
pl21411.show()
# Out:
# (14969, 2) Time taken  is 1.4884445269902546 min

# %%
# %matplotlib qt
from mds import landmark_MDS
import matplotlib.pyplot as plt
from scipy.spatial import distance
X=Xfdatapgr
colorx=df12
colx=np.array(colorx)
color=fill_color2(colx,17)
import random
lands = random.sample(range(0,X.shape[0],1),3000)
lands = np.array(lands,dtype=int)
Dl2 = distance.cdist(X[lands,:], X, 'euclidean')
start = time.time()
xl_21 = landmark_MDS(Dl2,lands,2)
print (xl_21.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))

# plt.figure()
# for color, i, target_name in zip(colors, [0, 1, 2], target_names):
#     plt.scatter(xl_2[y == i, 0], xl_2[y == i, 1], alpha=.8, color=color,label=target_name)
# plt.legend(loc='best', shadow=False, scatterpoints=1)
# plt.title('Landmark MDS of IRIS dataset')
# plt.show()
import matplotlib.pyplot as pl214111
pl214111.figure()
pl214111.rcParams["figure.figsize"] = [10.24,10.24]
pl214111.tight_layout()
pl214111.axis('off')
pl214111.scatter(xl_21[:,0], xl_21[:,1], marker='.',c=color)
pl214111.savefig(pref+'-LMDSsgr30k.png', format='png', dpi=100)
pl214111.show()
# Out:
# (14969, 2) Time taken  is 0.04736045996348063 min

# %%
# %matplotlib qt
from mds import landmark_MDS
import matplotlib.pyplot as plt
from scipy.spatial import distance
X=Xfdatapgr
colorx=df12
colx=np.array(colorx)
color=fill_color2(colx,17)
import random
lands = random.sample(range(0,X.shape[0],1),3000)
lands = np.array(lands,dtype=int)
Dl2 = distance.cdist(X[lands,:], X, 'euclidean')
start = time.time()
xl_211 = landmark_MDS(Dl2,lands,2)
print (xl_211.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))

# plt.figure()
# for color, i, target_name in zip(colors, [0, 1, 2], target_names):
#     plt.scatter(xl_2[y == i, 0], xl_2[y == i, 1], alpha=.8, color=color,label=target_name)
# plt.legend(loc='best', shadow=False, scatterpoints=1)
# plt.title('Landmark MDS of IRIS dataset')
# plt.show()
import matplotlib.pyplot as pl214111
pl214111.figure()
pl214111.rcParams["figure.figsize"] = [10.24,10.24]
pl214111.tight_layout()
pl214111.axis('off')
pl214111.scatter(xl_211[:,0], xl_211[:,1], marker='.',c=color)
pl214111.savefig(pref+'-LMDSssgr3000.png', format='png', dpi=100)
pl214111.show()
# Out:
# (14969, 2) Time taken  is 0.047799646854400635 min

# %%
# %matplotlib qt
import matplotlib.pyplot as pl21411
pl21411.figure()
pl21411.rcParams["figure.figsize"] = [10.24,10.24]
pl21411.tight_layout()
pl21411.axis('off')
pl21411.scatter(xl_2[:,0], xl_2[:,1], marker='.',c=color)
pl21411.savefig(pref+'-LMDSgr10.png', format='png', dpi=100)
pl21411.show()
import matplotlib.pyplot as pl214111
pl214111.figure()
pl214111.rcParams["figure.figsize"] = [10.24,10.24]
pl214111.tight_layout()
pl214111.axis('off')
pl214111.scatter(xl_21[:,0], xl_21[:,1], marker='.',c=color)
pl214111.savefig(pref+'-LMDSsgr3.png', format='png', dpi=100)
pl214111.show()
import matplotlib.pyplot as pl1442
pl1442.figure()
pl1442.rcParams["figure.figsize"] = [10.24,10.24]
pl1442.tight_layout()
pl1442.axis('off')
pl1442.scatter(grAryp3b[:,0], grAryp3b[:,1], marker='.',c=color)
pl1442.savefig(pref+'-mlpgrB.png', format='png', dpi=100)
pl1442.show()
import matplotlib.pyplot as pl14421
pl14421.figure()
pl14421.rcParams["figure.figsize"] = [10.24,10.24]
pl14421.tight_layout()
pl14421.axis('off')
pl14421.scatter(grAryp3s[:,0], grAryp3s[:,1], marker='.',c=color)
pl14421.savefig(pref+'-mlpgrS.png', format='png', dpi=100)
pl14421.show()
import matplotlib.pyplot as pl214112
pl214112.figure()
pl214112.rcParams["figure.figsize"] = [10.24,10.24]
pl214112.tight_layout()
pl214112.axis('off')
pl214112.scatter(trans_dataXgr[:,0], trans_dataXgr[:,1], marker='.',c=color)
pl214112.savefig(pref+'-MDSgr.png', format='png', dpi=100)
pl214112.show()

# %%
# Xfdatagr=np.array(grcoords[:,0:2])
# Xfdatapgr=np.array(grcoordp[:,0:3])
# start = time.time()
# Dh=squareform(pdist(Xfdatagr, (lambda u,v: haversine(u,v))))
# D=euclidean_distances(Xfdatapgr.astype(np.float64))
# print ('Time taken  is {} min\n'.format((time.time()-start)/60))
# Out:
# Time taken  is 16.67496300538381 min

# %%
start = time.time()
Dlmds=euclidean_distances(xl_2.astype(np.float64))
Dlmdss=euclidean_distances(xl_21.astype(np.float64))
#Dbh=euclidean_distances(tdata.astype(np.float64))
Dmds=euclidean_distances(trans_dataXgr.astype(np.float64))

#Dbe=euclidean_distances(tdatap.astype(np.float64))
Dmlp=euclidean_distances(grAryp3b.astype(np.float64))
D=D/D.max()
Dh=Dh/Dh.max()
Dlmds=Dlmds/Dlmds.max()
Dlmdss=Dlmdss/Dlmdss.max()
Dmds=Dmds/Dmds.max()
Dmlp=Dmlp/Dmlp.max()

print(mean_squared_error(Dh, D))

print(mean_squared_error(D, Dlmds))
print(mean_squared_error(D, Dlmdss))
print(mean_squared_error(D, Dmds))
print(mean_squared_error(D, Dmlp))
print('0.00009439121')
print ('Time taken  is {} min\n'.format((time.time()-start)/60))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-2c453903bb56> in <module>
#       3 Dlmdss=euclidean_distances(xl_21.astype(np.float64))
#       4 #Dbh=euclidean_distances(tdata.astype(np.float64))
# ----> 5 Dmds=euclidean_distances(trans_dataXgr.astype(np.float64))
#       6
#       7 #Dbe=euclidean_distances(tdatap.astype(np.float64))
#
# NameError: name 'trans_dataXgr' is not defined

# %%
import numpy as np
n = np.zeros((4,4))
print("%d bytes" % (n.size * n.itemsize))
# Out:
# 128 bytes

# %%
import matplotlib.pyplot as pl2141
pl2141.figure()
pl2141.rcParams["figure.figsize"] = [10.24,10.24]
pl2141.tight_layout()
pl2141.axis('off')
pl2141.scatter(Xfdatagr[:,0], Xfdatagr[:,1], marker='.',c=color)
pl2141.savefig(pref+'-groundgr.png', format='png', dpi=100)
pl2141.show()

# %%
# %matplotlib qt
colorx=df12
colx=np.array(colorx)
color=fill_color2(colx,17)
#color="0.1"
# import matplotlib.pyplot as plt3
# plt3.figure()
# plt3.rcParams["figure.figsize"] = [10.24,10.24]
# plt3.tight_layout()
# plt3.axis('off')
# plt3.scatter(Xtdata[:,0], Xtdata[:,1], marker='.',c=color)
# plt3.savefig(pref+'-23fmds.png', format='png', dpi=100)
# plt3.show()
import matplotlib.pyplot as pl2141
pl2141.figure()
pl2141.rcParams["figure.figsize"] = [10.24,10.24]
pl2141.tight_layout()
pl2141.axis('off')
pl2141.scatter(Xfdatagr[:,0], Xfdatagr[:,1], marker='.',c=color)
pl2141.savefig(pref+'-groundgr.png', format='png', dpi=100)
pl2141.show()

import matplotlib.pyplot as pl141
pl141.figure()
pl141.rcParams["figure.figsize"] = [10.24,10.24]
pl141.tight_layout()
pl141.axis('off')
pl141.scatter(grAryp2s[:,0], grAryp2s[:,1], marker='.',c=color)
pl141.savefig(pref+'-XhSmlpgr.png', format='png', dpi=100)
pl141.show()
import matplotlib.pyplot as pl1441
pl1441.figure()
pl1441.rcParams["figure.figsize"] = [10.24,10.24]
pl1441.tight_layout()
pl1441.axis('off')
pl1441.scatter(grAryp3s[:,0], grAryp3s[:,1], marker='.',c=color)
pl1441.savefig(pref+'-XeSmlpgr.png', format='png', dpi=100)
pl1441.show()
import matplotlib.pyplot as pl142
pl142.figure()
pl142.rcParams["figure.figsize"] = [10.24,10.24]
pl142.tight_layout()
pl142.axis('off')
pl142.scatter(grAryp2b[:,0], grAryp2b[:,1], marker='.',c=color)
pl142.savefig(pref+'-XhBmlpgr.png', format='png', dpi=100)
pl142.show()
import matplotlib.pyplot as pl1442
pl1442.figure()
pl1442.rcParams["figure.figsize"] = [10.24,10.24]
pl1442.tight_layout()
pl1442.axis('off')
pl1442.scatter(grAryp3b[:,0], grAryp3b[:,1], marker='.',c=color)
pl1442.savefig(pref+'-XeBmlpgr.png', format='png', dpi=100)
pl1442.show()

# %%
# %matplotlib qt
import os
import matplotlib.pyplot as plt8225
import scipy as sp
import scipy.misc
import numpy
import cv2
import imreg_dft as ird

plt8225.rcParams["figure.figsize"] = [20.48,20.48]
# im0 = plt2.imread('bmds.png')
# # the image to be transformed
# im1 = plt2.imread('bmlp.png')
im0 = numpy.array( cv2.imread(pref+'-groundgr.png',cv2.IMREAD_GRAYSCALE))
im1 = numpy.array(cv2.imread(pref+'-XhSmlpgr.png',cv2.IMREAD_GRAYSCALE))
print(im0.shape,im1.shape)
#im1 = cv2.flip(im1, 1)
result = ird.similarity(im0, im1, numiter=4,exponent='inf',order=3,filter_pcorr=2)

assert "timg" in result
# Maybe we don't want to show plots all the time
im3=result['timg']
tvec = result["tvec"].round(6)
ird.imshow(im0, im1, result['timg'])
plt8225.show()
#plt822.ylabel('mds','mlp','diff')
plt8225.savefig(pref+'-Xhsicpgr.png', format='png', dpi=100)
print("scale is {} angle is {} Translation is {}, success rate {:.6g}"
    .format(result['scale'], result['angle'],tuple(result["tvec"]), result["success"]))
# Out:
# (1024, 1024) (1024, 1024)
# scale is 0.8961912815621564 angle is -149.2240473408591 Translation is (-3.2322846301638606, 76.98969433934747), success rate 0.0220024

# %%
# %matplotlib qt
import os
import matplotlib.pyplot as plt8225
import scipy as sp
import scipy.misc
import numpy
import cv2
import imreg_dft as ird

plt8225.rcParams["figure.figsize"] = [20.48,20.48]
# im0 = plt2.imread('bmds.png')
# # the image to be transformed
# im1 = plt2.imread('bmlp.png')
im0 = numpy.array( cv2.imread(pref+'-groundgr.png',cv2.IMREAD_GRAYSCALE))
im1 = numpy.array(cv2.imread(pref+'-XeSmlpgr.png',cv2.IMREAD_GRAYSCALE))
print(im0.shape,im1.shape)
#im1 = cv2.flip(im1, 1)
result = ird.similarity(im0, im1, numiter=3,exponent='inf',order=3,filter_pcorr=2)

assert "timg" in result
# Maybe we don't want to show plots all the time
im3=result['timg']
tvec = result["tvec"].round(6)
ird.imshow(im0, im1, result['timg'])
plt8225.show()
#plt822.ylabel('mds','mlp','diff')
plt8225.savefig(pref+'-Xesicpgr.png', format='png', dpi=100)
print("scale is {} angle is {} Translation is {}, success rate {:.6g}"
    .format(result['scale'], result['angle'],tuple(result["tvec"]), result["success"]))
# Out:
# (1024, 1024) (1024, 1024)
# scale is 0.7301772414076619 angle is 25.86023364951899 Translation is (203.8360000784105, 165.09144248471944), success rate 0.0131424

# %%
# %matplotlib qt
import os
import matplotlib.pyplot as plt8225
import scipy as sp
import scipy.misc
import numpy
import cv2
import imreg_dft as ird

plt8225.rcParams["figure.figsize"] = [20.48,20.48]
# im0 = plt2.imread('bmds.png')
# # the image to be transformed
# im1 = plt2.imread('bmlp.png')
im0 = numpy.array( cv2.imread(pref+'-groundgr.png',cv2.IMREAD_GRAYSCALE))
im1 = numpy.array(cv2.imread(pref+'-XhBmlpgr.png',cv2.IMREAD_GRAYSCALE))
print(im0.shape,im1.shape)
#im1 = cv2.flip(im1, 1)
result = ird.similarity(im0, im1, numiter=2,exponent='inf',order=3,filter_pcorr=2)

assert "timg" in result
# Maybe we don't want to show plots all the time
im3=result['timg']
tvec = result["tvec"].round(6)
ird.imshow(im0, im1, result['timg'])
plt8225.show()
#plt822.ylabel('mds','mlp','diff')
plt8225.savefig(pref+'-Xhbicpgr.png', format='png', dpi=100)
print("scale is {} angle is {} Translation is {}, success rate {:.6g}"
    .format(result['scale'], result['angle'],tuple(result["tvec"]), result["success"]))

# %%
# %matplotlib qt
import os
import matplotlib.pyplot as plt8225
import scipy as sp
import scipy.misc
import numpy
import cv2
import imreg_dft as ird

plt8225.rcParams["figure.figsize"] = [20.48,20.48]
# im0 = plt2.imread('bmds.png')
# # the image to be transformed
# im1 = plt2.imread('bmlp.png')
im0 = numpy.array( cv2.imread(pref+'-groundgr.png',cv2.IMREAD_GRAYSCALE))
im1 = numpy.array(cv2.imread(pref+'-XeBmlpgr.png',cv2.IMREAD_GRAYSCALE))
print(im0.shape,im1.shape)
#im1 = cv2.flip(im1, 1)
result = ird.similarity(im0, im1, numiter=2,exponent='inf',order=3,filter_pcorr=2)

assert "timg" in result
# Maybe we don't want to show plots all the time
im3=result['timg']
tvec = result["tvec"].round(6)
ird.imshow(im0, im1, result['timg'])
plt8225.show()
#plt822.ylabel('mds','mlp','diff')
plt8225.savefig(pref+'-Xebicpgr.png', format='png', dpi=100)
print("scale is {} angle is {} Translation is {}, success rate {:.6g}"
    .format(result['scale'], result['angle'],tuple(result["tvec"]), result["success"]))

# %%
# %matplotlib qt
# colorx=df11
# colx=np.array(colorx)
# color=fill_color2(colx,17)
#color="0.1"
import matplotlib.pyplot as plt3
plt3.figure()
plt3.rcParams["figure.figsize"] = [10.24,10.24]
plt3.tight_layout()
plt3.axis('off')
plt3.scatter(Xtdata[:,0], Xtdata[:,1], marker='.',c=color)
plt3.savefig(pref+'-23fmds.png', format='png', dpi=100)
plt3.show()


import matplotlib.pyplot as pl4
pl4.figure()
pl4.rcParams["figure.figsize"] = [10.24,10.24]
pl4.tight_layout()
pl4.axis('off')
pl4.scatter(ryp2[:,0], ryp2[:,1], marker='.',c=color)
pl4.savefig(pref+'-23fmlp.png', format='png', dpi=100)
pl4.show()

# %%
# %matplotlib qt
import matplotlib.pyplot as plt33
plt33.figure()
plt33.rcParams["figure.figsize"] = [10.24,10.24]
plt33.tight_layout()
plt33.axis('off')
plt33.scatter(Xtdata[:,0], Xtdata[:,1], marker='.',c=color)
plt33.savefig(pref+'-33fmds.png', format='png', dpi=100)
plt33.show()


import matplotlib.pyplot as pl44
pl44.figure()
pl44.rcParams["figure.figsize"] = [10.24,10.24]
pl44.tight_layout()
pl44.axis('off')
pl44.scatter(ryp3[:,0], ryp3[:,1], marker='.',c=color)
pl44.savefig(pref+'-33fmlp.png', format='png', dpi=100)
pl44.show()

# %%
import os
import matplotlib.pyplot as plt822
import scipy as sp
import scipy.misc
import numpy
import cv2
import imreg_dft as ird
plt822.rcParams["figure.figsize"] = [20.48,20.48]
# im0 = plt2.imread('bmds.png')
# # the image to be transformed
# im1 = plt2.imread('bmlp.png')
im0 = numpy.array( cv2.imread(pref+'-33fmds.png',cv2.IMREAD_GRAYSCALE))
im1 = numpy.array(cv2.imread(pref+'-33fmlp.png',cv2.IMREAD_GRAYSCALE))
print(im0.shape,im1.shape)
#im1 = cv2.flip(im1, 1)
result = ird.similarity(im0, im1, numiter=6,exponent='inf',order=3,filter_pcorr=0)

assert "timg" in result
# Maybe we don't want to show plots all the time
im3=result['timg']
tvec = result["tvec"].round(6)
ird.imshow(im0, im1, result['timg'])
plt822.show()
#plt822.ylabel('mds','mlp','diff')
plt822.savefig(pref+'-3icp.png', format='png', dpi=100)
print("scale is {} angle is {} Translation is {}, success rate {:.6g}"
    .format(result['scale'], result['angle'],tuple(result["tvec"]), result["success"]))
# Out:
# (1024, 1024) (1024, 1024)
# scale is 0.9202227411707363 angle is -70.86147619217542 Translation is (13.027214095915383, -51.09209040843484), success rate 0.0168631

# %%
trans_dataX.min(),trans_dataX.max()
# Out:
# (-0.7390555517824855, 0.7233913581665572)

# %%
# %matplotlib qt
import matplotlib.pyplot as plt3
color=fill_color(mycities2)
plt3.figure()
plt3.rcParams["figure.figsize"] = [10.24,10.24]
plt3.tight_layout()
plt3.axis('off')
plt3.scatter(trans_dataX[:,0], trans_dataX[:,1], marker='.', c=color)
#plt3.scatter(trans_dataX[:,0], trans_dataX[:,1], marker='.',, c=color,c="0.1")
plt3.savefig(pref+'-231fmds.png', format='png', dpi=100)
plt3.show()


import matplotlib.pyplot as pl4
pl4.figure()
pl4.rcParams["figure.figsize"] = [10.24,10.24]
pl4.tight_layout()
pl4.axis('off')
pl4.scatter(ryp2[:,0], ryp2[:,1], marker='.',c=color)
pl4.savefig(pref+'-231fmlp.png', format='png', dpi=100)
pl4.show()

# %%
# %matplotlib qt
import matplotlib.pyplot as plt33
color=fill_color(mycities2)
plt33.figure()
plt33.rcParams["figure.figsize"] = [10.24,10.24]
plt33.tight_layout()
plt33.axis('off')
plt33.scatter(trans_dataX[:,0], trans_dataX[:,1], marker='.',c=color)
plt33.savefig(pref+'-331fmds.png', format='png', dpi=100)
plt33.show()


import matplotlib.pyplot as pl44
pl44.figure()
pl44.rcParams["figure.figsize"] = [10.24,10.24]
pl44.tight_layout()
pl44.axis('off')
pl44.scatter(ryp3[:,0], ryp3[:,1], marker='.',c=color)
pl44.savefig(pref+'-331fmlp.png', format='png', dpi=100)
pl44.show()

# %%
import os
import matplotlib.pyplot as plt822
import scipy as sp
import scipy.misc
import numpy
import cv2
import imreg_dft as ird
plt822.rcParams["figure.figsize"] = [20.48,20.48]
# im0 = plt2.imread('bmds.png')
# # the image to be transformed
# im1 = plt2.imread('bmlp.png')
im0 = numpy.array( cv2.imread(pref+'-331fmds.png',cv2.IMREAD_GRAYSCALE))
im1 = numpy.array(cv2.imread(pref+'-331fmlp.png',cv2.IMREAD_GRAYSCALE))
print(im0.shape,im1.shape)
#im1 = cv2.flip(im1, 1)
result = ird.similarity(im0, im1, numiter=3,exponent='inf',order=3,filter_pcorr=1)

assert "timg" in result
# Maybe we don't want to show plots all the time
im3=result['timg']
tvec = result["tvec"].round(6)
ird.imshow(im0, im1, result['timg'])
plt822.show()
#plt822.ylabel('mds','mlp','diff')
plt822.savefig(pref+'-31icp.png', format='png', dpi=100)
print("scale is {} angle is {} Translation is {}, success rate {:.6g}"
    .format(result['scale'], result['angle'],tuple(result["tvec"]), result["success"]))
# Out:
# (1024, 1024) (1024, 1024)
# scale is 0.7725301994667041 angle is 119.72504194325171 Translation is (44.08187950989884, 42.29399166805547), success rate 0.0216768

# %%
# Out:
# Time taken  is 3341.2145131866137 min
# (66863, 2)

# %%
start = time.time()
x=Xfdata
ryp2s =regressormodel2s.predict(x)
print (ryp2s.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))

start = time.time()
x=Xfdatap
ryp3s =regressormodel3s.predict(x)
print (ryp3s.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))
start = time.time()
x=Xfdata
ryp2b =regressormodel2b.predict(x)
print (ryp2b.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))
start = time.time()
x=Xfdatap
ryp3b =regressormodel3b.predict(x)
print (ryp3b.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))

# %%
# Out:
# (66863, 13)

# %%
lats=mycities2[:,0]/90
lons=mycities2[:,1]/180
lats.min(),lats.max() ,lons.min(),lons.max()
# Out:
# (-0.8649555555555556,
#  0.9090980000000001,
#  -0.9997395555555555,
#  0.9993518333333333)

# %%
lanlon=np.array([lats,lons]).T
lanlon.shape,lats.shape,lons.shape,mycities2.shape
# Out:
# ((66863, 2), (66863,), (66863,), (66863, 13))

# %%
mycities2=np.concatenate([mycities2, lanlon], axis=1)
mycities2.shape
# Out:
# (66863, 15)

# %%
pref=str(mycities2.shape[0]) + "-" + str(etime)+"-"

np.save(pref+'mycities2.npy', mycities2) 
#mycities2 = np.load(pref+'mycities2.npy')
mycities2[0]
# Out:
# array([0.25174, 0.78177, 'Al Mashnah', 'Asia', 8281922.0, 'YE',
#        0.9999995827674866, 0.5083611607551575, 0.4990955889225006,
#        0.11741009791434, 0.4725528055259599, 0.039605464672004466,
#        0.39775179721844284, 0.0027971111111111113, 0.004343166666666666],
#       dtype=object)

# %%
# Out:
# -1.0 0.982631422638385
# -0.7390555517824855 0.7233913581665572

# %%
# fdata=np.append(x_train , np.array([[87,180],[-80,-180]]), axis=0)
# fdatae=np.append(x_test , np.array([[87,180],[-80,-180]]), axis=0)
from sklearn.model_selection import train_test_split
x_train ,x_test = train_test_split(mycities2.copy(),test_size=0.8) 
fdata=np.array(x_train[:,0:2])
Nfdata=np.array(x_train[:,13:15])
fdatap=np.array(x_train[:,6:9])
tdata=np.array(x_train[:,9:11])
tdatap=np.array(x_train[:,11:13])


fdatae=np.array(x_test[:,0:2])
Nfdatae=np.array(x_test[:,13:15])
fdataep=np.array(x_test[:,6:9])
tdatae=np.array(x_test[:,9:11])
tdataep=np.array(x_test[:,11:13])
x_train.shape ,x_test.shape
# Out:
# ((13372, 15), (53491, 15))

# %%
myplot(fdata[:,0],fdata[:,1])
myplot(Nfdata[:,0],Nfdata[:,1])

# %%
# %matplotlib qt


# myplot(fdata2[:,0],fdata2[:,1],fdata2[:,2])

# myplot(fdata[:,0],fdata[:,1])

# myplot(fdataM[:,0],fdataM[:,1])
# fdata=mycities2[:,0:2].copy()
# fdata=np.append(mycities2[:,0:2].copy() , np.array([[87,180],[-80,-180]]), axis=0)
# fdatae=np.append(fdata , np.array([[87,180],[-80,-180]]), axis=0)
# print(x_train[:,0].min(),x_train[:,0].max(),x_train[:,1].min(),x_train[:,1].max())
# print(x_test[:,0].min(),x_test[:,0].max(),x_test[:,1].min(),x_test[:,1].max())
# print(fdatae[:,0].min(),fdatae[:,0].max(),fdatae[:,1].min(),fdatae[:,1].max())
# print(fdata[:,0].min(),fdata[:,0].max(),fdata[:,1].min(),fdata[:,1].max())

# %%
# print(fdata.shape,fdatae.shape,fdatae[fdatae.shape[0]-1],mycities3[fdatae.shape[0]-1])
# fdata=mycities2[:,0:2].copy()
# fdatae=np.append(fdata , np.array([[87,180],[-80,-180]]), axis=0)

# %%
# lats=fdatae[:,0]
# lons=fdatae[:,1]
# #fdataepo=p2cart(lats,lons);
# # fdataep=p2cart(lats,lons)

# latsp=fdata[:,0]
# lonsp=fdata[:,1]

# # fdatap=p2cart(latsp,lonsp)
# color=fill_color(mycities2)

# #myplot(fdataep[:,0],fdataep[:,1],fdataep[:,2])
# #myplot(fdatap[:,0],fdatap[:,1],fdatap[:,2])
# fdataep.shape,fdatap.shape

# %%
# %matplotlib qt

# %%
# tdata2,etime,D=doMDS3(fdata)
# #MERGE RESULTS
# #mycitiesFD=np.concatenate([mycities2, tdata], axis=1)

# #color=fill_color(mycitiesFD)
# tdata2.shape

# %%
# %matplotlib qt
# import matplotlib.pyplot as plt
# plt.figure()
# plt.rcParams["figure.figsize"] = [5.12,5.12]
# plt.tight_layout()
# plt.axis('off')
# plt.scatter(tdata[:,0], tdata[:,1], marker='.',c="0.1")
# plt.savefig('Pmds.png', format='png', dpi=100)
# plt.show()


# import matplotlib.pyplot as pl
# pl.figure()
# pl.rcParams["figure.figsize"] = [5.12,5.12]
# pl.tight_layout()
# pl.axis('off')
# pl.scatter(trans_data2[:,0], trans_data2[:,1], marker='.',c="0.1")
# pl.savefig('Pmlp.png', format='png', dpi=100)
# pl.show()

# %%
# %matplotlib qt

# %%
# %matplotlib qt
import matplotlib.pyplot as plt3
plt3.figure()
plt3.rcParams["figure.figsize"] = [5.12,5.12]
plt3.tight_layout()
plt3.axis('off')
plt3.scatter(tdatae[:,0], tdatae[:,1], marker='.',c="0.1")
plt3.savefig(pref+'-mds.png', format='png', dpi=100)
plt3.show()


import matplotlib.pyplot as pl4
pl4.figure()
pl4.rcParams["figure.figsize"] = [5.12,5.12]
pl4.tight_layout()
pl4.axis('off')
pl4.scatter(tdataep[:,0], tdataep[:,1], marker='.',c="0.1")
pl4.savefig(pref+'-mlp.png', format='png', dpi=100)
pl4.show()

# %%
# plt.figure()
# plt.rcParams["figure.figsize"] = [5.12,5.12]
# plt.tight_layout()
# plt.axis('off')
# plt.scatter(trans_data[:,0], trans_data[:,1], marker='.',)
# #plt.savefig('mds.png', format='png', dpi=100)
# plt.show()

# %%
# pref="30021-130.37367326815922-"

# tdata=np.load(pref+'tdata.npy' ) 
# fdatap=np.load(pref+'fdatap.npy' ) 
# tdatae=np.load(pref+'tdatae.npy' ) 
# fdataep=np.load(pref+'fdataep.npy' )
# fdata=np.load(pref+'fdata.npy' )
# trans_data=np.load(pref+'trans_data.npy' )
# trans_data2=np.load(pref+'trans_data.npy' )
# D=np.load(pref+'D.npy') 
# D2=np.load(pref+'D2.npy' ) 
# x_train=np.load(pref+'x_train.npy' ) 
# x_test=np.load(pref+'x_test.npy' ) 
# mycities2=np.load(pref+'mycities2.npy' ) 


#     a=squareform(pdist(fdata, (lambda u,v: haversine(u,v))))
# #     distance_matrixX  = squareform(pdist(xx,'sqeuclidean'))
# #     distance_matrix2  = squareform(pdist(fdataM,'sqeuclidean'))
# #     distance_matrix7  = squareform(pdist(gvdata,'sqeuclidean'))
# #     distance_matrix = squareform(pdist(fdata2,'sqeuclidean'))
#     #distance_matrixc = squareform(pdist(fdatac,'sqeuclidean'))
#     distance_matrixc2  = euclidean_distances(fdataM.astype(np.float64))

# %%
# from numpy.linalg import matrix_rank
# t0=time.time()
# print(D.shape)
# rank=matrix_rank(D)
# print(rank)
# print("Time min: " ,(time.time()-t0)/60)
# np.save(pref+str(rank)+'D.npy', D)

# %%
# #MDS
# tdata,pos2,btransformed22,transformed22,tdata7,etime,D=doMDS(fdata,fdataM,fdata2)
# #MERGE RESULTS
# mycitiesFn3=np.concatenate([mycities2, xyMerc], axis=1)
# mycitiesFn7=np.concatenate([mycities2, tdata7], axis=1)
# mycitiesFn=np.concatenate([mycities2, transformed22], axis=1)
# mycitiesFnb=np.concatenate([mycities2, btransformed22], axis=1)
# mycitiesFn2=np.concatenate([mycities2, pos2], axis=1)
# mycitiesFD=np.concatenate([mycities2, tdata], axis=1)
# mycitiesFD2=np.concatenate([mycities2, fdata2], axis=1)
# mycitiesc=np.concatenate([mycities2, fdatac], axis=1)
# color=fill_color(mycitiesFn)

# %%
# #mycitiesFD[0]


# tdat=tdata.copy()
# tdate=tdatae.copy()
# kdata=fdata.copy()
# kdatae=fdatae.copy()
# #from sklearn.metrics import mean_squared_error
# # A=euclidean_distances(fdataM.astype(np.float64))
# # B=euclidean_distances(btransformed22.astype(np.float64))
# # C=squareform(pdist(fdata, (lambda u,v: haversine(u,v))))
# # D=squareform(pdist(tdata, (lambda u,v: haversine(u,v))))
# # print(mean_squared_error(A, B),mean_squared_error(C, D))
# # A=A/A.max()
# # B=B/B.max()
# # C=C/C.max()
# # D=D/D.max()

# %%
# %matplotlib qt
# myplot(tdat[:,0],tdat[:,1])
# myplot(tdate[:,0],tdate[:,1])

# %%
# myplot(fdataep[:,0],fdataep[:,1],fdataep[:,2])

# %%
# %matplotlib qt
import numpy as np
import time
import matplotlib.pyplot as pl
from sklearn import neural_network 
from sklearn import datasets
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, explained_variance_score
from sklearn.model_selection import cross_val_predict
import sklearn.model_selection as  cross_validation
# ###########################################
# Load data

# Creating Regression Design Matrix 
x=fdatae
y=tdatae
#y=trans_data
#x_train, x_test, y_train, y_test= cross_validation.train_test_split(x, y, test_size=0.2, random_state=42)
# ######################################################################
# Fit regression model
n_fig=0
#n_size=500
#n_size=(45,2,11,)
n_size= (300, 300)
start = time.time()
start2 = time.time()
for name, nn_unit in [
        ('MLP using ReLU', neural_network.MLPRegressor(hidden_layer_sizes=n_size,activation='relu', solver='lbfgs'))
        ]:
    regressormodel=nn_unit.fit(x,y)
    # Y predicted values
    yp =nn_unit.predict(x)
    rmse =np.sqrt(mean_squared_error(y,yp))
    #Calculation 10-Fold CV
    yp_cv = cross_val_predict(regressormodel, x, y, cv=10)
    rmsecv=np.sqrt(mean_squared_error(y,yp_cv))
    print('Method: %s' %name)
    print('RMSE on the data: %.4f' %rmse)
    print('RMSE on 10-fold CV: %.4f' %rmsecv)
    print ('Time taken  is {} min\n'.format((time.time()-start)/60))
    start = time.time()
#     n_fig=n_fig+1
#     pl.figure(n_fig)
#     pl.plot(yp, y,'ro')
#     pl.plot(yp_cv, y,'bo', alpha=0.25, label='10-folds CV')
#     pl.xlabel('predicted')
#     pl.title('Method: %s' %name)
#     pl.ylabel('real')
#     pl.grid(True)
#     pl.show()
print ('Time taken  is {} min\n'.format((time.time()-start2)/60))

# %%
#%matplotlib qt
import numpy as np
import time
import matplotlib.pyplot as pl
from sklearn import neural_network 
from sklearn import datasets
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, explained_variance_score
from sklearn.model_selection import cross_val_predict
import sklearn.model_selection as  cross_validation
# ###########################################
# Load data

# Creating Regression Design Matrix 
x=Nfdatae
y=tdatae
#y=trans_data
#x_train, x_test, y_train, y_test= cross_validation.train_test_split(x, y, test_size=0.2, random_state=42)
# ######################################################################
# Fit regression model
n_fig=0
#n_size=500
#n_size=(45,2,11,)
n_size= (300, 300)
start = time.time()
start2 = time.time()
for name, nn_unit in [
        ('MLP using ReLU', neural_network.MLPRegressor(hidden_layer_sizes=n_size,activation='relu', solver='lbfgs'))
        ]:
    regressormodel2=nn_unit.fit(x,y)
    # Y predicted values
    yp2 =nn_unit.predict(x)
    rmse =np.sqrt(mean_squared_error(y,yp2))
    #Calculation 10-Fold CV
    yp_cv2 = cross_val_predict(regressormodel2, x, y, cv=10)
    rmsecv=np.sqrt(mean_squared_error(y,yp_cv2))
    print('Method: %s' %name)
    print('RMSE on the data: %.4f' %rmse)
    print('RMSE on 10-fold CV: %.4f' %rmsecv)
    print ('Time taken  is {} min\n'.format((time.time()-start)/60))
    start = time.time()
#     n_fig=n_fig+1
#     pl.figure(n_fig)
#     pl.plot(yp, y,'ro')
#     pl.plot(yp_cv, y,'bo', alpha=0.25, label='10-folds CV')
#     pl.xlabel('predicted')
#     pl.title('Method: %s' %name)
#     pl.ylabel('real')
#     pl.grid(True)
#     pl.show()
print ('Time taken  is {} min\n'.format((time.time()-start2)/60))

# %%
#%matplotlib qt
import numpy as np
import time
import matplotlib.pyplot as pl
from sklearn import neural_network 
from sklearn import datasets
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, explained_variance_score
from sklearn.model_selection import cross_val_predict
import sklearn.model_selection as  cross_validation
# ###########################################
# Load data

# Creating Regression Design Matrix 
x=fdataep
y=tdataep
#y=trans_data
#x_train, x_test, y_train, y_test= cross_validation.train_test_split(x, y, test_size=0.2, random_state=42)
# ######################################################################
# Fit regression model
n_fig=0
#n_size=500
#n_size=(45,2,11,)
n_size= (300, 300)
start = time.time()
start2 = time.time()
for name, nn_unit in [
        ('MLP using ReLU', neural_network.MLPRegressor(hidden_layer_sizes=n_size,activation='relu', solver='lbfgs'))
        ]:
    regressormodel3=nn_unit.fit(x,y)
    # Y predicted values
    yp3 =nn_unit.predict(x)
    rmse =np.sqrt(mean_squared_error(y,yp3))
    #Calculation 10-Fold CV
    yp_cv3 = cross_val_predict(regressormodel3, x, y, cv=10)
    rmsecv=np.sqrt(mean_squared_error(y,yp_cv3))
    print('Method: %s' %name)
    print('RMSE on the data: %.4f' %rmse)
    print('RMSE on 10-fold CV: %.4f' %rmsecv)
    print ('Time taken  is {} min\n'.format((time.time()-start)/60))
    start = time.time()
#     n_fig=n_fig+1
#     pl.figure(n_fig)
#     pl.plot(yp, y,'ro')
#     pl.plot(yp_cv, y,'bo', alpha=0.25, label='10-folds CV')
#     pl.xlabel('predicted')
#     pl.title('Method: %s' %name)
#     pl.ylabel('real')
#     pl.grid(True)
#     pl.show()
print ('Time taken  is {} min\n'.format((time.time()-start2)/60))

# %%
# %matplotlib qt
#myplot(trans_data[:,0],trans_data[:,1])
myplot(tdatae[:,0],tdatae[:,1])
myplot(yp[:,0],yp[:,1])
myplot(yp2[:,0],yp2[:,1])

# %%
myplot(tdataep[:,0],tdataep[:,1])
myplot(yp3[:,0],yp3[:,1])
# start = time.time()
# x=fdata
# yp =regressormodel2.predict(x)
# print (yp.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))

# %%
import pickle
filename = pref+'regressormodel.sav'
pickle.dump(regressormodel, open(filename, 'wb'))
#regressormodel = pickle.load(open(filename, 'rb'))

filename = pref+'regressormodel2.sav'
pickle.dump(regressormodel2, open(filename, 'wb'))
#regressormodel = pickle.load(open(filename, 'rb'))
filename = pref+'regressormodel3.sav'
pickle.dump(regressormodel3, open(filename, 'wb'))
#regressormodel = pickle.load(open(filename, 'rb'))

# %%
start = time.time()
x=fdata
ryp =regressormodel.predict(x)
print (ryp.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))

# %%
start = time.time()
x=Nfdata
ryp2 =regressormodel2.predict(x)
print (ryp2.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))

# %%
start = time.time()
x=fdatap
ryp3 =regressormodel3.predict(x)
print (ryp3.shape,'Time taken  is {} min\n'.format((time.time()-start)/60))

# %%
# %matplotlib qt
import matplotlib.pyplot as plt331
plt331.figure()
plt331.rcParams["figure.figsize"] = [10.24,10.24]
plt331.tight_layout()
plt331.axis('off')
plt331.scatter(tdata[:,0], tdata[:,1], marker='.',c="0.1")
plt331.savefig(pref+'-1fmds.png', format='png', dpi=100)
plt331.show()


import matplotlib.pyplot as pl441
pl441.figure()
pl441.rcParams["figure.figsize"] = [10.24,10.24]
pl441.tight_layout()
pl441.axis('off')
pl441.scatter(ryp[:,0], ryp[:,1], marker='.',c="0.1")
pl441.savefig(pref+'-1fmlp.png', format='png', dpi=100)
pl441.show()

# %%
# %matplotlib qt
import matplotlib.pyplot as plt3
plt3.figure()
plt3.rcParams["figure.figsize"] = [10.24,10.24]
plt3.tight_layout()
plt3.axis('off')
plt3.scatter(tdatap[:,0], tdatap[:,1], marker='.',c="0.1")
plt3.savefig(pref+'-2fmds.png', format='png', dpi=100)
plt3.show()


import matplotlib.pyplot as pl4
pl4.figure()
pl4.rcParams["figure.figsize"] = [10.24,10.24]
pl4.tight_layout()
pl4.axis('off')
pl4.scatter(ryp2[:,0], ryp2[:,1], marker='.',c="0.1")
pl4.savefig(pref+'-2fmlp.png', format='png', dpi=100)
pl4.show()

# %%
# %matplotlib qt
import matplotlib.pyplot as plt33
plt33.figure()
plt33.rcParams["figure.figsize"] = [10.24,10.24]
plt33.tight_layout()
plt33.axis('off')
plt33.scatter(tdatap[:,0], tdatap[:,1], marker='.',c="0.1")
plt33.savefig(pref+'-3fmds.png', format='png', dpi=100)
plt33.show()


import matplotlib.pyplot as pl44
pl44.figure()
pl44.rcParams["figure.figsize"] = [10.24,10.24]
pl44.tight_layout()
pl44.axis('off')
pl44.scatter(ryp3[:,0], ryp3[:,1], marker='.',c="0.1")
pl44.savefig(pref+'-3fmlp.png', format='png', dpi=100)
pl44.show()

# %%
# %matplotlib qt

# %%
import os
import matplotlib.pyplot as plt22
import scipy as sp
import scipy.misc
import numpy
import cv2
import imreg_dft as ird
plt22.rcParams["figure.figsize"] = [20.48,20.48]
# im0 = plt2.imread('bmds.png')
# # the image to be transformed
# im1 = plt2.imread('bmlp.png')
im0 = numpy.array( cv2.imread(pref+'-1fmds.png',cv2.IMREAD_GRAYSCALE))
im1 = numpy.array(cv2.imread(pref+'-1fmlp.png',cv2.IMREAD_GRAYSCALE))
print(im0.shape,im1.shape)
result = ird.similarity(im0, im1, numiter=3,exponent='inf',order=3,filter_pcorr=0)

assert "timg" in result
# Maybe we don't want to show plots all the time
im3=result['timg']
tvec = result["tvec"].round(6)
ird.imshow(im0, im1, result['timg'])
plt22.show()
print("scale is {} angle is {} Translation is {}, success rate {:.6g}"
    .format(result['scale'], result['angle'],tuple(result["tvec"]), result["success"]))

# %%
import os
import matplotlib.pyplot as plt922
import scipy as sp
import scipy.misc
import numpy
import cv2
import imreg_dft as ird
plt922.rcParams["figure.figsize"] = [20.48,20.48]
# im0 = plt2.imread('bmds.png')
# # the image to be transformed
# im1 = plt2.imread('bmlp.png')
im0 = numpy.array( cv2.imread(pref+'-2fmds.png',cv2.IMREAD_GRAYSCALE))
im1 = numpy.array(cv2.imread(pref+'-2fmlp.png',cv2.IMREAD_GRAYSCALE))
print(im0.shape,im1.shape)
#im1 = cv2.flip(im1, 1)
result = ird.similarity(im0, im1, numiter=3,exponent='inf',order=3,filter_pcorr=1)

assert "timg" in result
# Maybe we don't want to show plots all the time
im3=result['timg']
tvec = result["tvec"].round(6)
ird.imshow(im0, im1, result['timg'])
plt922.show()
print("scale is {} angle is {} Translation is {}, success rate {:.6g}"
    .format(result['scale'], result['angle'],tuple(result["tvec"]), result["success"]))

# %%
import os
import matplotlib.pyplot as plt822
import scipy as sp
import scipy.misc
import numpy
import cv2
import imreg_dft as ird
plt822.rcParams["figure.figsize"] = [20.48,20.48]
# im0 = plt2.imread('bmds.png')
# # the image to be transformed
# im1 = plt2.imread('bmlp.png')
im0 = numpy.array( cv2.imread(pref+'-3fmds.png',cv2.IMREAD_GRAYSCALE))
im1 = numpy.array(cv2.imread(pref+'-3fmlp.png',cv2.IMREAD_GRAYSCALE))
print(im0.shape,im1.shape)
#im1 = cv2.flip(im1, 1)
result = ird.similarity(im0, im1, numiter=3,exponent='inf',order=3,filter_pcorr=1)

assert "timg" in result
# Maybe we don't want to show plots all the time
im3=result['timg']
tvec = result["tvec"].round(6)
ird.imshow(im0, im1, result['timg'])
plt822.show()
print("scale is {} angle is {} Translation is {}, success rate {:.6g}"
    .format(result['scale'], result['angle'],tuple(result["tvec"]), result["success"]))

# %%
# #%matplotlib qt
# d1=3
# col='eggplant'
# ceo='('+ str(lat)+','+str(lon)+')'
# if zoom_lon > 0:
#     ceo=ceo +' latw('+str(lat-zoom_lat/2) +','+ str(lat+zoom_lat/2) +')' + 'lonw(' +str(lon-zoom_lon/2)+','+ str(lon+zoom_lon/2)+') '+str(zoom_lat)+','+str(zoom_lon)


# #visualize2DData(mycitiesFn7,"M2 MDS CARTESIAN - EUCLIDEAN  DISTANCE"+ceo,d1,col)
# visualize2DData(mycitiesFD,"*M1 MDS ORIGINAL - HAVERSINE  DISTANCE"+ceo,d1,col)
# #visualize2DData(mycitiesFn,"M3 ORIGINAL (NMDS + PCA) HAVERSINE DISTANCE "+ceo,d1,col)

# #visualize2DData(mycitiesFn3,"Arxiko SE MERCATO "+ceo,d1,col)

# %%
# visualize2DData(mycitiesFDReg,"M2 MDS regression "+ceo,d1,col)
# # d1=5
# # col='eggplant'
# # ceo='('+ str(lat)+','+str(lon)+')'
# # #visualize2DData(mycitiesFn7,"M2 MDS CARTESIAN - EUCLIDEAN  DISTANCE"+ceo,d1,col)
# # visualize2DData(mycitiesFD,"*M1 MDS ORIGINAL - HAVERSINE  DISTANCE"+ceo,d1,col)
# # #visualize2DData(mycitiesFn,"M3 ORIGINAL (NMDS + PCA) HAVERSINE DISTANCE "+ceo,d1,col)
# # visualize2DData(mycitiesFnb,"M3 MDS ORIGINAL default euclidean DISTANCE "+ceo,d1,col)
# # #visualize2DData(mycitiesFn3,"Arxiko SE MERCATO "+ceo,d1,col)

# %%
# import numpy as np
# import time
# import matplotlib.pyplot as pl
# from sklearn import neural_network 
# from sklearn import datasets
# from sklearn.metrics import mean_squared_error, explained_variance_score
# from sklearn.model_selection import cross_val_predict
# import sklearn.model_selection as  cross_validation
# # ###########################################
# # Load data

# # Creating Regression Design Matrix 
# x=fdataepo
# y=tdatae
# #x_train, x_test, y_train, y_test= cross_validation.train_test_split(x, y, test_size=0.2, random_state=42)
# # ######################################################################
# # Fit regression model
# n_fig=0
# n_size=3000
# start = time.time()
# start2 = time.time()
# for name, nn_unit in [
#         ('MLP using ReLU', neural_network.MLPRegressor(hidden_layer_sizes=n_size,activation='relu', solver='lbfgs')), ('MLP using Logistic Neurons', neural_network.MLPRegressor(hidden_layer_sizes=n_size,activation='logistic')), ('MLP using TanH Neurons', neural_network.MLPRegressor(hidden_layer_sizes=n_size,activation='tanh',solver='lbfgs'))
#         ]:
#     regressormodel=nn_unit.fit(x,y)
#     # Y predicted values
#     yp =nn_unit.predict(x)
#     rmse =np.sqrt(mean_squared_error(y,yp))
#     #Calculation 10-Fold CV
#     yp_cv = cross_val_predict(regressormodel, x, y, cv=10)
#     rmsecv=np.sqrt(mean_squared_error(y,yp_cv))
#     print('Method: %s' %name)
#     print('RMSE on the data: %.4f' %rmse)
#     print('RMSE on 10-fold CV: %.4f' %rmsecv)
#     print ('Time taken  is {} min\n'.format((time.time()-start)/60))
#     start = time.time()
#     n_fig=n_fig+1
#     pl.figure(n_fig)
#     pl.plot(yp, y,'ro')
#     pl.plot(yp_cv, y,'bo', alpha=0.25, label='10-folds CV')
#     pl.xlabel('predicted')
#     pl.title('Method: %s' %name)
#     pl.ylabel('real')
#     pl.grid(True)
#     pl.show()
# print ('Time taken  is {} min\n'.format((time.time()-start2)/60))

# %%
# #isomap
# tdata,pos2,btransformed22,transformed22,tdata7=doISO(fdata,fdataM,fdatac)
# #MERGE RESULTS

# mycitiesFn31=np.concatenate([mycities2, xyMerc], axis=1)
# mycitiesFn71=np.concatenate([mycities2, tdata7], axis=1)
# mycitiesFn1=np.concatenate([mycities2, transformed22], axis=1)
# mycitiesFnb1=np.concatenate([mycities2, btransformed22], axis=1)
# mycitiesFn21=np.concatenate([mycities2, pos2], axis=1)
# mycitiesFD1=np.concatenate([mycities2, tdata], axis=1)
# mycitiesFD21=np.concatenate([mycities2, fdata2], axis=1)
# mycitiesc1=np.concatenate([mycities2, fdatac], axis=1)
# color=fill_color(mycitiesFn1)

# %%
# from sklearn.metrics import mean_squared_error
# A=euclidean_distances(fdatac.astype(np.float64))
# B=euclidean_distances(transformed22.astype(np.float64))
# C=squareform(pdist(fdata, (lambda u,v: haversine(u,v))))
# print(mean_squared_error(A, B),mean_squared_error(C, D))
# A=A/A.max()
# B=B/B.max()
# C=C/C.max()

# print(mean_squared_error(A, B),mean_squared_error(C, B))

# %%
# %matplotlib qt
# d1=5
# col='eggplant'
# ceo='('+ str(lat)+','+str(lon)+')'
# if zoom_lon > 0:
#     ceo=ceo +' latw('+str(lat-zoom_lat/2) +','+ str(lat+zoom_lat/2) +')' + 'lonw(' +str(lon-zoom_lon/2)+','+ str(lon+zoom_lon/2)+') '+str(zoom_lat)+','+str(zoom_lon)


# #visualize2DData(mycitiesFn71,"M2 MDS CARTESIAN - EUCLIDEAN  DISTANCE"+ceo,d1,col)
# #visualize2DData(mycitiesFD1,"*M1 MDS ORIGINAL - HAVERSINE  DISTANCE"+ceo,d1,col)
# visualize2DData(mycitiesFn1,"ISOMAP EUCLIDEAN  DISTANCE "+ceo,d1,col)
# #visualize2DData(mycitiesFnb1,"M3 MDS ORIGINAL default euclidean DISTANCE "+ceo,d1,col)
# #visualize2DData(mycitiesFn31,"Arxiko SE MERCATO "+ceo,d1,col)

# %%
# d1=3
# col='eggplant'
# ceo='('+ str(lat)+','+str(lon)+')'
# #visualize2DData(mycitiesFn21,"M2 MDS CARTESIAN - EUCLIDEAN  DISTANCE"+ceo,d1,col)
# #visualize2DData(mycitiesFD1,"*M1 MDS ORIGINAL - HAVERSINE  DISTANCE"+ceo,d1,col)
# visualize2DData(mycitiesFn1,"ISOMAP EUCLIDEAN  DISTANCE "+ceo,d1,col)
# #visualize2DData(mycitiesFnb1,"M3 MDS ORIGINAL default euclidean DISTANCE "+ceo,d1,col)
# #visualize2DData(mycitiesFn31,"Arxiko SE MERCATO "+ceo,d1,col)

# %%
# #LLE
# tdata2d = manifold.LocallyLinearEmbedding(n_neighbors=100,n_components = 2).fit_transform(fdataM)
# tdata3d = manifold.LocallyLinearEmbedding(n_neighbors=70,n_components = 2).fit_transform(fdatac)

# %%
# mycitiesFn73=np.concatenate([mycities2, tdata2d], axis=1)
# mycitiesFn23=np.concatenate([mycities2, tdata3d], axis=1)

# %%
# %matplotlib qt
# d1=3
# col='eggplant'
# ceo='('+ str(lat)+','+str(lon)+')'
# if zoom_lon > 0:
#     ceo=ceo +' latw('+str(lat-zoom_lat/2) +','+ str(lat+zoom_lat/2) +')' + 'lonw(' +str(lon-zoom_lon/2)+','+ str(lon+zoom_lon/2)+') '+str(zoom_lat)+','+str(zoom_lon)

# visualize2DData(mycitiesFn23,"LLE euclidean 3D"+ceo,d1,col)
# visualize2DData(mycitiesFn73,"LLE euclidean 2D "+ceo,d1,col)

# %%
# d1=5
# col='eggplant'
# ceo='('+ str(lat)+','+str(lon)+')'
# visualize2DData(mycitiesFn23,"LLE euclidean 3D"+ceo,d1,col)
# visualize2DData(mycitiesFn73,"LLE euclidean 2D "+ceo,d1,col)

# %%
# from sklearn.metrics import mean_squared_error
# A=euclidean_distances(tdata2d.astype(np.float64))
# B=euclidean_distances(tdata3d.astype(np.float64))
# C=squareform(pdist(fdata, (lambda u,v: haversine(u,v))))
# D=euclidean_distances(fdataM.astype(np.float64))
# E=euclidean_distances(fdatac.astype(np.float64))
# print(mean_squared_error(A, D),mean_squared_error(E, B))
# A=A/A.max()
# B=B/B.max()
# C=C/C.max()
# E=E/E.max()
# D=D/D.max()
# print(mean_squared_error(A, D),mean_squared_error(E, B))

# %%
#LLE
#tdata,pos2,btransformed22,transformed22,tdata7=doLLE(fdata,fdataM,fdata2)
#MERGE RESULTS
#mycitiesFn33=np.concatenate([mycities2, xyMerc], axis=1)
#mycitiesFn73=np.concatenate([mycities2, tdata7], axis=1)
#mycitiesFn3=np.concatenate([mycities2, transformed22], axis=1)
#mycitiesFnb3=np.concatenate([mycities2, btransformed22], axis=1)
#mycitiesFn23=np.concatenate([mycities2, pos2], axis=1)
#mycitiesFD3=np.concatenate([mycities2, tdata], axis=1)
#mycitiesFD23=np.concatenate([mycities2, fdata2], axis=1)
#mycitiesc3=np.concatenate([mycities2, fdatac], axis=1)
#color=fill_color(mycitiesFn3)

# %%
# %matplotlib qt
# d1=5
# col='eggplant'
# ceo='('+ str(lat)+','+str(lon)+')'
# if zoom_lon > 0:
#     ceo=ceo +' latw('+str(lat-zoom_lat/2) +','+ str(lat+zoom_lat/2) +')' + 'lonw(' +str(lon-zoom_lon/2)+','+ str(lon+zoom_lon/2)+') '+str(zoom_lat)+','+str(zoom_lon)
# #visualize2DData(mycitiesFn73,"M2 MDS CARTESIAN - EUCLIDEAN  DISTANCE"+ceo,d1,col)
# visualize2DData(mycitiesFD3,"*M1 MDS ORIGINAL - HAVERSINE  DISTANCE"+ceo,d1,col)
# visualize2DData(mycitiesFn3,"M3 ORIGINAL (NMDS + PCA) HAVERSINE DISTANCE "+ceo,d1,col)
# visualize2DData(mycitiesFnb3,"M3 MDS ORIGINAL default euclidean DISTANCE "+ceo,d1,col)
# visualize2DData(mycitiesFn33,"Arxiko SE MERCATO "+ceo,d1,col)

# %%
# d1=3
# col='eggplant'
# ceo='('+ str(lat)+','+str(lon)+')'
# #visualize2DData(mycitiesFn71,"M2 MDS CARTESIAN - EUCLIDEAN  DISTANCE"+ceo,d1,col)
# visualize2DData(mycitiesFn23,"*M1 MDS ORIGINAL - HAVERSINE  DISTANCE"+ceo,d1,col)
# #visualize2DData(mycitiesFn3,"M3 ORIGINAL (NMDS + PCA) HAVERSINE DISTANCE "+ceo,d1,col)
# visualize2DData(mycitiesFn73,"M3 MDS ORIGINAL default euclidean DISTANCE "+ceo,d1,col)
# visualize2DData(mycitiesFn33,"Arxiko SE MERCATO "+ceo,d1,col)

# %%
# fdata2
# %matplotlib qt

# %%
# pref='earth_'

# %%
# #SAVE DATA

# np.save(pref+'mycitiesFn3.npy', mycitiesFn3) 
# np.save(pref+'mycitiesFn7.npy', mycitiesFn7) 
# np.save(pref+'mycitiesFn.npy', mycitiesFn) 
# np.save(pref+'mycitiesFn7.npy', mycitiesFn7) 
# np.save(pref+'mycitiesFnb.npy', mycitiesFnb) 
# np.save(pref+'mycitiesFn2.npy', mycitiesFn2) 
# np.save(pref+'mycitiesFD2.npy', mycitiesFD2) 
# np.save(pref+'mycitiesFD.npy', mycitiesFD) 
# np.save(pref+'mycitiesc.npy', mycitiesc)

# %%
# #LOAD DATA
# mycitiesFn3 = np.load(pref+'mycitiesFn3.npy')
# mycitiesFn7 = np.load(pref+'mycitiesFn7.npy')
# mycitiesFn = np.load(pref+'mycitiesFn.npy')
# mycitiesFn7 = np.load(pref+'mycitiesFn7.npy')
# mycitiesFnb = np.load(pref+'mycitiesFnb.npy')
# mycitiesFn2 = np.load(pref+'mycitiesFn2.npy')
# mycitiesFD2 = np.load(pref+'mycitiesFD2.npy')

# mycitiesc = np.load(pref+'mycitiesc.npy')
# coords1 = np.load(pref+'Acoords1.npy')
# coords2 = np.load(pref+'Acoords2.npy')
# color=fill_color(mycitiesFn)
# mycitiesFD = np.load(pref+'mycitiesFD.npy')

# %%
# #LOAD DATA
# mycitiesFn2 = np.load('AmycitiesFn2.npy')
# mycitiesFn = np.load('AmycitiesFn.npy')
# mycitiesFnb = np.load('AmycitiesFnb.npy')
# mycitiesFn7 = np.load('AmycitiesFn7.npy')
# mycitiesFn3 = np.load('AmycitiesFn3.npy')
# mycitiesFD = np.load('AmycitiesFD.npy')
# mycitiesFD2 = np.load('AmycitiesFD2.npy')
# mycitiesc = np.load('Amycitiesc.npy')
# coords1 = np.load('Acoords1.npy')
# coords2 = np.load('Acoords2.npy')
# color=fill_color(mycitiesFn)

# %%
# #PLOT DATA
# %matplotlib qt
# plotmap(coords1,"LOADED DATA")
# xyMerc=plotmap(coords2,"FILTERED DATA")
# #visualize2DData(mycitiesFn2,"M3 MDS EUCLIDEAN DISTANCE")
# visualize2DData(mycitiesFn,"M2 NMDS EUCLIDEAN DISTANCE ")
# visualize2DData(mycitiesFn7,"M3 MDS HAVERSINE DISTANCE")
# visualize2DData(mycitiesFD,"M1 MDS EUCLIDEAN DISTANCE")
# #visualize2DData(mycitiesFn3,"Arxiko SE MERCATO ")
# visualize3DData(mycitiesFD2,"Arxiko cartesian")
# #visualize2DData(mycitiesFD,"2MDS EUCLIDEAN DISTANCE")
# #visualize3DData(mycitiesC,"1Arxiko cartesian")
